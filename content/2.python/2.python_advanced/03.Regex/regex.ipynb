# %% [markdown]
# # Regular expressions (regex) : love or hate?

# %% [markdown]
# ![commit strip](http://www.commitstrip.com/wp-content/uploads/2014/02/Strips-Le-dernier-des-vrais-codeurs-650-finalenglsih.jpg)

# %% [markdown]
# Regular expressions are used in almost all languages. It is a very powerful tool to check if the content of a variable has the shape you expect.
#
# For example, if you retrieve a phone number, you expect the variable to be composed of numbers and spaces (or dashes) but nothing more.
#
# Regular expressions not only warn you of an unwanted character but also delete/modify all those that are not desirable.

# %% [markdown]
# **There are two ways to use regular expressions:**
# * The first consists in calling the function with the pattern as the first parameter, and the string to be analyzed as the second parameter.
# * The second way is to compile the regex, and then use the methods of the created object to analyze a string passed as an argument. This method speeds up processing when a regex is used several times.

# %%
import re

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Searches the pattern in the previous string and return a `MatchObject` if matches are found,
# otherwise returns `None`.
print(re.search(pattern, string))
# Out:
# <re.Match object; span=(1, 2), match=' '>

# %%
pattern = "[ ]"
string = "I am fine ! There are still 6 months left :()"

# Cuts the string according to the occurrence of the pattern.
print(re.split(pattern, string))
# Out:
# ['I', 'am', 'fine', '!', 'There', 'are', 'still', '6', 'months', 'left', ':()']

# %% [markdown]
# ### A little syntax
#
#     [xy]  A possible segment list. Example[abc] equals: a, b or c
#
#     (x|y) Indicates a multiple choice type (ps|ump) equals "ps" OR "UMP"
#
#     \d    the segment is composed only of numbers, which is equivalent to[0-9].
#
#     \D    the segment is not composed of numbers, which is equivalent to[^0-9].
#
#     \s    A space, which is equivalent to [ \t\n\r\r\f\v].
#
#     \S    No space, which is equivalent to[^ ^ \t\n\r\f\v].
#
#     \w    Alphanumeric presence, which is equivalent to[a-zA-Z0-9_].
#
#     \W    No alphanumeric presence[^a-zA-Z0-9_].
#
#     \     Is an escape character

# %% [markdown]
# Let's try it.
#
# If the answer is not `None`, it means the match matches. GREY is indeed a name beginning with GR followed by a character and ending with Y.

# %%
print(re.match("GR(.)?Y", "GREY"))
# (.)? means that we expect 0 or 1 character.
# 0 or 1 because of the `?` following the character `.`, which means any character
# Out:
# <re.Match object; span=(0, 4), match='GREY'>

# %%
pattern = "GR(.)?Y"
string = "GREY"

result = re.match(pattern, string)
print(result)

# It is equal to
compiled = re.compile(pattern)
result = compiled.match(string)
print(result)
# Out:
# <re.Match object; span=(0, 4), match='GREY'>
# <re.Match object; span=(0, 4), match='GREY'>

# %%
#  So in a loop the second syntax is nicer
pattern = "GR(.)?Y"
compiled = re.compile(pattern)
l = ["GREY 'S", "GRAY", "GREYISH", "A GREY"]

for elem in l:
    result = compiled.match(elem)
    print(elem, result)
# Out:
# GREY 'S <re.Match object; span=(0, 4), match='GREY'>
# GRAY <re.Match object; span=(0, 4), match='GRAY'>
# GREYISH <re.Match object; span=(0, 4), match='GREY'>
# A GREY None

# %% [markdown]
# In the following, we search for specific expressions in a string.

# %%
print(re.findall("GR(.)?Y", "GREY"))
# so here we are looking for a unique element (.)? between GR and Y
# Out:
# ['E']

# %%
# Ditto for two characters to be found
re.findall("G(.)?(.)?Y", "GREY")
# Out:
# [('R', 'E')]

# %% [markdown]
# To keep only numbers.

# %%
# Only numbers
print(re.findall("([0-9]+)", "Hello I live on the 7th floor of 220 street of sims"))
# "+" Means 1 or more characters
# Out:
# ['7', '220']

# %% [markdown]
# And conversely, if you only want to keep the words.

# %%
# Only words
print(re.findall("([A-z]+)", "Hello I live on the 7th floor of 220 street of sims"))
# Out:
# ['Hello', 'I', 'live', 'on', 'the', 'th', 'floor', 'of', 'street', 'of', 'sims']

# %% [markdown]
# ### Stop, we recap !

# %% [markdown]
# Character | Meaning
# :-------------------------:|:-------------------------:
# **.** | **Refers to any character.**
# **^** | **Indicates that the beginning of the string must match <br/> (i.e. a string can only match if it starts in the same way, <br /> if it is preceded by spaces or a line break)**
# **$** | **Indicates that the end of the chain must match <br /> (the same remark as above applies, but at the end level).**
# **{n}**|**Indicates that the previous character must be repeated n times.**
# **{n, m}**|**Indicates that the previous character must be repeated between n and m times.**
#  *| **The previous character can be repeated none or several times. <br />For example, ab* may correspond to: a, ab, or a followed by any number of b.**
# **+**|**The previous character can be repeated once or several times. <br/>For example, to ab+ corresponds an a followed by any number of b.**
# **?**|**The previous character can be repeated zero or once.<br /> For example, to ab? correspond ab and a.**
# **\w** | **it corresponds to any alphabetical character, it is equivalent to [a-zA-Z].**
# **\W** | **it corresponds to everything that is not an alphabetical character.**
# **\d** | **it corresponds to any numeric character, i.e. it is equivalent to[0-9].**
# **\D** | **it corresponds to everything that is not a numeric character.**

# %% [markdown]
# ![alt text](http://www.codercaste.com/wp-content/uploads/2013/01/regex.gif)

# %% [markdown]
# ### Some useful resources
# http://www.rexegg.com/regex-quickstart.html
# http://www.dreambank.net/regex.html#examples
# https://pythex.org/ *(Pythex is a real-time regular expression editor for Python, a quick way to test your regular expressions.)*
# https://regex101.com/
# *(Regex101 is online regex editor and debugger. Regex101 allows you to create, debug, test and have your expressions explained for PHP, PCRE, Python, Golang and JavaScript. The website also features a community where you can share useful expressions.)*

# %% [markdown]
# #### How to check that the entered string is that of a number ?

# %%
number = input("Your number : ")
if re.match("^[0-9]+$", number):
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number.")
# Out:
# The string entered is NOT a number.

# %% [markdown]
# Another way

# %%
compiled = re.compile("^[0-9]+$")
if compiled.search(number) is not None:
    print("The string entered is a number.")
else:
    print("The string entered is NOT a number")
# Out:
# The string entered is NOT a number

# %% [markdown]
# ## Drill

# %% [markdown]
# **1. Create a regex that finds integers without size limit.**

# %%
s = "sssgdds8sfsfs"
print(re.findall('\d+',"sssgdds8sfsfs"))
# Out:
# ['8']

# %% [markdown]
# **2. Create a regex that finds negative integers without size limit.**

# %%
s = "sssgdds-8sfsfs"
print(re.findall('-\d+', s))
# Out:
# ['-8']

# %% [markdown]
# **3. Create a regex that finds (positive or negative) integers without size limit.**

# %%
import re
s = "sssgdds-8s8fsfs"
print(re.findall('-?\d*\.{0,1}\d', s))
# Out:
# ['-8', '8']

# %% [markdown]
# **4. Capture all the numbers of the following sentence :**

# %%
import re
text = "21 scouts and 3 tanks fought against 4,003 protestors, so the manager was not 100.00% happy."
print(re.findall('[\d]+[.,\d]+|[\d]*[.][\d]+|[\d]+',text))
# Out:
# ['21', '3', '4,003', '100.00']

# %% [markdown]
# **5. Find all words that end with 'ly'.**

# %%
text = "He had prudently disguised himself but was quickly captured by the police."
print(re.findall('\w+ly',text))
# Out:
# ['prudently', 'quickly']

# %% [markdown]
# **6. License plate number**
# A license plate consists of 2 capital letters, a dash ('-'), 3 digits, a dash ('-') and finally 2 capital letters. Write a script to check that an input string is a license plate.
# If it's correct, print `"good"`. If it's not correct, print `"Not good"`.

# %%
plate = input("Enter your license plate number: ")
if re.match("[A-Z]{2}-[0-9]{3}-[A-Z]{2}", plate):
    print("good")
else:
    print("not good")
# Out:
# good

# %% [markdown]
# **7 . Address IPV4**
# An IPv4 address is composed of 4 numbers between 0 and 255 separated by '.'
# Write a script to verify that a string entered is that of an IPv4 address.

# %%
ip = input("Enter your IP address :")
if re.match('^((25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.){3}(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)$', ip):
   print("Acceptable IPv4 address")
else:
   print("Unacceptable IPv4 address")
# Out:
# Unacceptable IPv4 address

# %% [markdown]
# **8. Valid Mail**
# An email is composed of alphanumeric characters followed by `@` and a domain name.
# Write a script that checks that the string entered by a user is indeed that of an email, otherwise ask him to re-enter it again (until he gets a valid email).

# %%
import re
mail = input("Enter your email :")
if re.match('^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$', mail):
    print("valid email")
else:
    print("Re-enter your email ")
# Out:
# Re-enter your email

# %% [markdown]
# **9. Valid Password**
# Write an additional script that verifies the password (obviously if the email is valid) where the only specificity of the password is that it has to contain at least 6 characters.

# %%
password = input("Enter your password :")
if re.match('.{6}',password):
    print("valid password")
else:
    print("invalid password")
# Out:
# invalid password

# %% [markdown]
# **10. Valid Password bis**
# The password must now contain at least 6 characters AND
#
# - at least one lowercase letter AND
# - at least one uppercase letter AND
# - at least one number AND
# - at least one special character (among `$#@`).

# %%
password = input("Enter your password :")
if re.match('^.*(?=.{6,})(?=.*\d)(?=.*[a-z])(?=.*[A-Z])(?=.*[@#$]).*$',password):
    print("valid password")
else:
    print("invalid password")
# Out:
# invalid password

# %% [markdown]
# **11. Search by groups**
# It is possible to search by groups, and it is very powerful!
# `?P<x>\w+` means the capture of a "group" named `x`, this group is composed of at least (`+`) one alphanumeric  character `(\w)`.

# %%
m = re.search(
    "Welcome to (?P<where>\w+) ! You are (?P<age>\d+) years old ?",
    "Welcome to Olivier ! You are 32 years old ?",
)
print(m.group("where"))
print(m.group("age"))
# Out:
# Olivier
# 32

# %%
# Another Example
m = re.search(
    "^(?P<who>\w*)[.]?(?P<who2>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)",
    "audrey.boulevart@benextcomapgny.com",
)
if m is not None:
    print(m.group("who"))
    print(m.group("who2"))
    print(m.group("operator"))
    print(m.group("zone"))
# Out:
# audrey
# boulevart
# benextcomapgny
# com

# %% [markdown]
# Load the file `./data/mail.txt` and clean it with the regex. The goal is to retrieve the last name, first name, operator and zone, as in the previous example. Store each of those into their own separate list.

# %%
import re
last_name=[]
first_name=[]
operator=[]
zone=[]

list_mail = open("./data/mail.txt")
f=list_mail.readlines()

for line in f:
    m = re.search("^(?P<last_name>\w*)[.]?(?P<first_name>\w*)@(?P<operator>\w+)[.](?P<zone>\w+$)",line)
    if m is not None:
        last_name.append(m.group("last_name"))
        first_name.append(m.group("first_name"))
        operator.append(m.group("operator"))
        zone.append(m.group("zone"))

print(last_name)
print(first_name)
print(operator)
print(zone)
# Out:
# ['aikin', 'moore', 'halknutson', 'alexnorquist', 'monte', 'knutsondan', 'lepage', 'chapman_ben', 'upson1544', '552966959', 'soloman_ziegler', 'ortiz', 'ashwoon_hank', 'pettigrew', 'doranedward', 'mills_joe', 'yang', 'ike', 'larrytrebil', 'davis_ike', 'davidsonhal', 'john8733', 'johnfletcher', 'cataldi_larry', 'rogerfietzer', 'edward4185', 'hancock_matthew', 'solberg_cast', 'georgepak', 'ike', 'tapia_quinn', '795419860', 'jack', 'joe', 'ben', 'pettigrewgeorge', 'boyd_carl', 'yocum_mark', 'george59', 'johnsen2201', 'schutzlarry', 'quizoz', 'matthew8227', 'georgemoody', 'lawicki589', 'doran7947', 'mark', 'waltermartin', 'george', 'ferry', 'fred', 'jurgensonpeter', 'stevefietzer', 'sonderling_caswell', 'johnsen', 'mccormack', 'roberts', 'valente', 'ory_walter', 'tyirwin', 'paulferry', 'george', 'mccormack', '851886792', 'zeaser_aaron', 'adam', 'tisler', 'severson_george', 'otto', 'illingsworth', 'alex685', 'hancock_valente', 'paul9581', 'sawyer_chambers', 'johnsen', 'aaron', 'schiebel2392', 'mccormackedward', 'tapia1876', 'quizoz9628', 'rogerstahl', 'schutz_johnsen', 'carlupson', 'larry349', 'matthew', 'mcginnis', 'nugent_jack', 'wagle_john', 'chapmannathan', 'hal536', '472510707', 'thomas', 'adamillingsworth', 'peterstahl', 'victortandy', 'adam', 'ike3831', 'timfletcher', 'frank', '566486749', '675340599', 'davis_nathan', '253159777', 'edwardschutz', 'sagar_carl', '331837931', 'aaronbongard', 'ty9516', 'schustersteve', 'moody_schiebel', 'soloman_ramachandran', 'victor630', 'yang_trebil', 'hoffman_zeller', 'ripka_thomas', 'vader', 'ottochambers', 'tylulloff', '263935905', 'carlvail', 'hanktisler', 'uddin1510', 'mccormack', 'vader', 'nelsonmark', 'stahl', 'timirwin', 'davis9134', 'davidziegler', 'carl1959', 'alexkeller', '469322116', 'monte7207', 'fredtiernan', 'fietzer', 'benquinn', 'hal', 'sweeney', 'fletcher_monte', 'woothomas', 'walter', 'dinkins', '950099319', 'roger', 'tim', 'sawyer', 'ben', 'carlmills', 'markboyd', '887934540', 'ortizjack', 'roberts_myers', 'soloman8370', 'alex3716', 'tim', 'thompson85', 'reyes', 'dinkinsroger', 'mills9634', '821464747', 'valente_hydinger', 'schiebel1467', 'larryschiebel', 'jagtap', 'edward', 'matthewcataldi', 'zeller', 'duffman', 'ottoortiz', 'delorenzo', 'miller_keller', 'illingsworth', 'nelson', 'rogers_john', 'tyresnick', 'hal', 'tiernan6950', 'mills', 'casal', 'hankupson', 'irwin_yang', 'napier', 'edward', 'rogers_lawicki', 'tapia_upson', 'uddin_yocum', 'bongardroger', 'victor', 'ty', 'paultiernan', 'roger836', 'pettigrew', 'johnsen4863', '890280316', 'weinstein', 'alexschmitt', 'dan', 'steve', 'matthewfrick', '237336989', 'larry6016', 'otto5489', 'bongard_ty', '169102677', 'upson', 'hal', 'sonderling_mark', '430581778', 'walterkassing', 'victorceledon', 'kassing', 'duffman6005', 'frank', 'uddinotto', '703979481', 'paul', 'nugent', 'alex', 'aaronsweeney', 'knutson_celedon', 'tydoran', 'millerhal', 'adamnuttle', 'ashwoon8609', 'mcginnis_reardon', 'ramachandran', 'monteshaffer', 'monte', 'pettigrew9750', 'yocum_dan', 'darnell8483', 'pettigrewlarry', 'ben5039', 'mcginnis', 'roger', 'adamtisler', 'matthew3420', 'john8770', 'hesch_zeller', 'christensen_ben', 'walter', 'ben8671', 'frankjagtap', 'peternuttle', 'victor8847', 'ferry', '690377034', 'lepageroger', 'john', '4709006', 'kaskel5284', 'hanktiernan', 'ripka2474', 'cataldi_matthew', 'steve6967', 'irwincarl', 'wakefieldjoe', 'nathansagar', 'hydinger_larry', 'frank', 'schuster5868', 'rogerschwager', '163622426', 'baxstercarl', 'aikin', 'tisler_reyes', 'monte1021', 'quizoz', 'vail_soukup', 'thomassonderling', 'frankaikin', 'aaronillingsworth', '859491337', 'paul', 'waltertisler', 'ferro_caswell', 'george', 'timorwig', 'jones', 'hoffman', 'matthew', 'larry2207', 'rice_sonderling', 'nuttleben', 'dewalt_martin', 'ikekassing', '240044289', 'otto', 'ferro', 'hankanderson', 'dan', 'orwig_sweeney', 'bencaswell', 'chambers', '579081959', 'moore', 'thomas', 'orwig', 'hal', 'alex9835', 'nathanripka', 'sonderling', 'matthew', 'monte2098', 'victor', '8 ...
# ['joe', '', '', '', 'hylan', '', '', '', '', '', '', 'mark', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'yang', '', '', '', '', '', '', 'joe', '', '', '', '', '', '', '', 'victor', 'weiss', '', '', '', 'walter', '', 'hank', '', '', '', '', '', 'carl', '', '', '', 'roger', '', 'nuttle', '', '', '', '', '', 'tim', 'roberts', '', '', '', '', '', '', '', '', 'linde', '', '', '', '', '', '', 'casal', '', '', '', 'sellon', '', '', 'schickowski', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'hal', '', '', '', '', '', '', 'carl', '', '', '', '', '', '', '', '', '', '', '', '', '', 'weiss', 'otto', '', '', '', '', '', 'myers', 'trusela', 'adam', 'jagtap', '', '', '', '', '', '', '', '', '', 'jack', '', '', '', '', '', '', 'fred', 'haworth', '', '', '', '', '', '', '', '', '', '', 'yang', '', '', 'hank', '', '', 'aaron', 'schickowski', '', '', '', '', '', 'schwager', '', '', 'victor', '', '', 'roger', '', 'uddin', 'stahl', '', '', '', '', '', '', 'hal', '', '', '', '', '', '', '', 'ventotla', '', '', 'nugent', '', '', '', '', '', '', '', '', '', 'mark', '', '', '', '', '', '', '', 'dan', 'vogal', '', '', '', '', '', 'soulis', '', '', '', '', 'paul', '', '', 'zeaser', '', '', '', '', '', '', '', '', '', '', 'yates', '', '', '', '', '', '', '', '', '', '', '', '', '', 'eastman', '', '', '', '', '', 'roger', 'trusela', '', '', '', '', '', '', '', 'edward', '', 'deitz', '', '', 'victor', '', 'fred', '', '', '', '', '', '', 'duffman', '', 'tiernan', '', '', '', '', '', '', '', '', '', '', '', '', '', 'john', '', '', '', 'fletcher', '', '', '', '', '', '', 'bongard', '', '', '', '', '', '', 'fred', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'monte', '', '', 'moore', '', '', '', '', '', '', '', 'darnell', '', 'peter', 'stahl', 'aaron', '', '', '', '', '', '', '', '', '', '', '', '', 'mccord', '', '', '', '', '', '', '', '', 'mark', '', '', '', '', '', '', 'fletcher', '', '', '', '', '', 'roger', '', 'jack', '', 'severson', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'fietzer', '', '', '', '', '', '', '', 'matthew', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'tiernan', '', '', '', '', '', '', 'dinkins', 'steve', '', '', 'roger', '', '', '', '', '', '', '', '', '', 'mark', 'jack', 'woo', '', 'irwin', '', '', '', '', '', '', '', '', '', '', '', '', '', 'stahl', '', '', '', '', '', '', '', 'mccormack', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'mark', '', '', '', '', '', '', 'zeller', '', '', '', '', '', '', 'casal', '', '', '', '', '', '', 'miller', '', 'roberts', 'matthew', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'david', '', 'thomas', '', '', '', '', '', '', '', '', '', '', 'reyes', '', '', '', '', 'walter', '', '', '', '', '', '', 'vanderpoel', '', '', '', '', 'norquist', '', '', '', '', '', '', 'mark', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'carl', '', 'weinstein', '', '', 'dan', '', '', '', '', '', '', '', '', '', '', '', '', 'thomas', '', '', 'monte', '', '', '', '', '', '', '', 'steve', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'moody', 'weinstein', '', '', '', 'jack', '', '', '', 'sandstrom', '', '', '', '', '', '', '', '', 'weinstein', '', '', 'martin', '', 'ventotla', '', '', '', '', 'rice', '', 'fred', '', '', '', '', 'yocum', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'hal', '', 'deitz', 'matthew', '', '', 'roger', '', '', 'rogers', '', 'mcginnis', '', 'steve', '', '', '', '', '', 'schwager', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'ty', '', 'alex', '', '', '', '', 'edward', '', '', '', '', '', '', 'thomas', '', '', '', '', '', '', '', 'carl', '', '', '', '', '', 'victor', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'hal', 'illingsworth', '', '', 'ulrich', 'wagner', '', '', 'carl', '', '', '', '', ...
# ['odul', 'imail', 'email', 'proton', 'belgaximus', 'belgaximus', 'gaagle', 'napster', 'youhoo', 'belgaximus', 'email', 'napster', 'imail', 'proton', 'napster', 'imail', 'email', 'ecoin', 'email', 'odul', 'hotmoille', 'youhoo', 'youhoo', 'napster', 'imail', 'gaagle', 'belgaximus', 'gaagle', 'gaagle', 'ecoin', 'gaagle', 'imail', 'gaagle', 'ecoin', 'ecoin', 'odul', 'napster', 'youhoo', 'ecoin', 'imail', 'email', 'napster', 'hotmoille', 'hotmoille', 'hotmoille', 'gaagle', 'email', 'ecoin', 'hotmoille', 'gaagle', 'odul', 'proton', 'ecoin', 'napster', 'odul', 'napster', 'proton', 'gaagle', 'proton', 'proton', 'hotmoille', 'youhoo', 'imail', 'youhoo', 'belgaximus', 'proton', 'hotmoille', 'proton', 'proton', 'belgaximus', 'hotmoille', 'hotmoille', 'email', 'belgaximus', 'email', 'imail', 'hotmoille', 'proton', 'imail', 'belgaximus', 'odul', 'ecoin', 'napster', 'odul', 'youhoo', 'imail', 'gaagle', 'napster', 'youhoo', 'napster', 'odul', 'hotmoille', 'youhoo', 'gaagle', 'youhoo', 'email', 'proton', 'imail', 'gaagle', 'email', 'proton', 'ecoin', 'gaagle', 'hotmoille', 'hotmoille', 'napster', 'odul', 'belgaximus', 'proton', 'hotmoille', 'gaagle', 'hotmoille', 'imail', 'imail', 'email', 'belgaximus', 'imail', 'email', 'youhoo', 'napster', 'ecoin', 'email', 'proton', 'proton', 'imail', 'odul', 'hotmoille', 'imail', 'imail', 'youhoo', 'gaagle', 'hotmoille', 'gaagle', 'email', 'gaagle', 'proton', 'email', 'gaagle', 'email', 'napster', 'napster', 'proton', 'imail', 'gaagle', 'hotmoille', 'belgaximus', 'napster', 'ecoin', 'belgaximus', 'email', 'gaagle', 'email', 'odul', 'ecoin', 'proton', 'proton', 'email', 'youhoo', 'odul', 'odul', 'hotmoille', 'proton', 'ecoin', 'proton', 'imail', 'youhoo', 'email', 'email', 'youhoo', 'ecoin', 'email', 'youhoo', 'odul', 'gaagle', 'imail', 'napster', 'belgaximus', 'belgaximus', 'proton', 'odul', 'gaagle', 'email', 'youhoo', 'gaagle', 'ecoin', 'gaagle', 'napster', 'youhoo', 'napster', 'youhoo', 'gaagle', 'email', 'gaagle', 'ecoin', 'imail', 'odul', 'ecoin', 'hotmoille', 'hotmoille', 'email', 'youhoo', 'gaagle', 'ecoin', 'gaagle', 'gaagle', 'hotmoille', 'belgaximus', 'hotmoille', 'napster', 'ecoin', 'hotmoille', 'youhoo', 'belgaximus', 'youhoo', 'ecoin', 'ecoin', 'proton', 'odul', 'ecoin', 'hotmoille', 'belgaximus', 'hotmoille', 'youhoo', 'youhoo', 'youhoo', 'proton', 'proton', 'proton', 'proton', 'napster', 'email', 'imail', 'hotmoille', 'gaagle', 'email', 'gaagle', 'hotmoille', 'napster', 'email', 'proton', 'email', 'proton', 'napster', 'napster', 'ecoin', 'imail', 'gaagle', 'proton', 'imail', 'napster', 'belgaximus', 'youhoo', 'hotmoille', 'odul', 'odul', 'belgaximus', 'ecoin', 'email', 'odul', 'proton', 'youhoo', 'imail', 'imail', 'proton', 'napster', 'imail', 'hotmoille', 'proton', 'proton', 'napster', 'odul', 'hotmoille', 'youhoo', 'napster', 'belgaximus', 'hotmoille', 'gaagle', 'email', 'napster', 'youhoo', 'imail', 'imail', 'gaagle', 'proton', 'belgaximus', 'gaagle', 'odul', 'napster', 'imail', 'imail', 'belgaximus', 'proton', 'youhoo', 'email', 'ecoin', 'imail', 'gaagle', 'imail', 'imail', 'email', 'belgaximus', 'napster', 'gaagle', 'odul', 'email', 'proton', 'hotmoille', 'gaagle', 'napster', 'email', 'ecoin', 'youhoo', 'odul', 'odul', 'gaagle', 'gaagle', 'hotmoille', 'hotmoille', 'hotmoille', 'ecoin', 'hotmoille', 'proton', 'napster', 'ecoin', 'ecoin', 'proton', 'email', 'proton', 'gaagle', 'hotmoille', 'belgaximus', 'gaagle', 'hotmoille', 'imail', 'hotmoille', 'youhoo', 'imail', 'odul', 'email', 'napster', 'ecoin', 'odul', 'imail', 'hotmoille', 'proton', 'gaagle', 'proton', 'odul', 'youhoo', 'proton', 'gaagle', 'ecoin', 'odul', 'email', 'email', 'hotmoille', 'odul', 'gaagle', 'youhoo', 'gaagle', 'gaagle', 'napster', 'napster', 'email', 'napster', 'gaagle', 'proton', 'proton', 'youhoo', 'gaagle', 'email', 'proton', 'hotmoille', 'napster', 'belgaximus', 'odul', 'napster', 'ecoin', 'youhoo', 'belgaximus', 'imail', 'hotmoille', 'email', 'gaagle', 'gaagle', 'proton', 'youhoo', 'imail', 'youhoo', 'email',  ...
# ['xyz', 'gov', 'xyz', 'com', 'net', 'org', 'xyz', 'hu', 'hu', 'hu', 'tech', 'me', 'io', 'hu', 'net', 'xyz', 'hu', 'io', 'org', 'io', 'apple', 'com', 'me', 'com', 'apple', 'gov', 'gov', 'apple', 'me', 'com', 'io', 'tech', 'apple', 'tech', 'com', 'me', 'me', 'com', 'gov', 'io', 'apple', 'tech', 'me', 'com', 'me', 'tech', 'io', 'gov', 'hu', 'com', 'tech', 'tech', 'tech', 'tech', 'net', 'xyz', 'net', 'xyz', 'hu', 'tech', 'com', 'gov', 'xyz', 'hu', 'apple', 'net', 'tech', 'org', 'hu', 'gov', 'com', 'net', 'tech', 'xyz', 'gov', 'gov', 'xyz', 'com', 'tech', 'apple', 'apple', 'tech', 'me', 'me', 'tech', 'xyz', 'hu', 'gov', 'org', 'net', 'io', 'com', 'xyz', 'me', 'hu', 'tech', 'apple', 'xyz', 'io', 'net', 'org', 'com', 'net', 'net', 'org', 'me', 'xyz', 'net', 'tech', 'me', 'org', 'hu', 'me', 'me', 'tech', 'org', 'io', 'gov', 'tech', 'me', 'com', 'org', 'net', 'me', 'xyz', 'apple', 'me', 'tech', 'tech', 'apple', 'com', 'tech', 'hu', 'net', 'org', 'com', 'xyz', 'apple', 'com', 'tech', 'io', 'gov', 'net', 'io', 'gov', 'org', 'tech', 'me', 'apple', 'net', 'gov', 'tech', 'gov', 'me', 'me', 'hu', 'hu', 'apple', 'xyz', 'gov', 'tech', 'io', 'net', 'gov', 'com', 'net', 'org', 'net', 'xyz', 'me', 'org', 'gov', 'tech', 'tech', 'io', 'xyz', 'tech', 'xyz', 'xyz', 'xyz', 'gov', 'org', 'xyz', 'apple', 'me', 'hu', 'net', 'gov', 'io', 'xyz', 'tech', 'io', 'apple', 'me', 'io', 'org', 'apple', 'me', 'com', 'io', 'org', 'tech', 'xyz', 'me', 'io', 'gov', 'me', 'com', 'tech', 'xyz', 'apple', 'hu', 'io', 'org', 'apple', 'apple', 'org', 'tech', 'apple', 'xyz', 'org', 'org', 'hu', 'tech', 'org', 'com', 'tech', 'gov', 'com', 'xyz', 'xyz', 'tech', 'tech', 'tech', 'xyz', 'xyz', 'tech', 'hu', 'apple', 'com', 'com', 'tech', 'com', 'gov', 'io', 'org', 'apple', 'gov', 'gov', 'tech', 'org', 'io', 'tech', 'me', 'hu', 'gov', 'org', 'apple', 'xyz', 'gov', 'tech', 'tech', 'com', 'net', 'gov', 'io', 'gov', 'apple', 'apple', 'com', 'io', 'com', 'hu', 'io', 'apple', 'com', 'hu', 'io', 'net', 'xyz', 'io', 'apple', 'hu', 'net', 'io', 'com', 'tech', 'hu', 'xyz', 'net', 'gov', 'me', 'apple', 'net', 'hu', 'com', 'me', 'tech', 'me', 'org', 'com', 'xyz', 'net', 'io', 'hu', 'net', 'com', 'tech', 'net', 'tech', 'hu', 'me', 'io', 'tech', 'apple', 'xyz', 'apple', 'net', 'gov', 'com', 'com', 'io', 'com', 'io', 'gov', 'com', 'org', 'xyz', 'net', 'com', 'gov', 'com', 'me', 'apple', 'tech', 'me', 'tech', 'com', 'com', 'org', 'io', 'com', 'com', 'io', 'gov', 'apple', 'apple', 'org', 'me', 'com', 'tech', 'org', 'hu', 'apple', 'tech', 'hu', 'gov', 'io', 'apple', 'net', 'io', 'com', 'hu', 'org', 'apple', 'tech', 'gov', 'org', 'com', 'me', 'xyz', 'hu', 'hu', 'tech', 'gov', 'apple', 'hu', 'tech', 'xyz', 'apple', 'net', 'org', 'com', 'org', 'com', 'io', 'gov', 'gov', 'gov', 'net', 'net', 'gov', 'tech', 'com', 'apple', 'net', 'com', 'hu', 'gov', 'tech', 'xyz', 'org', 'xyz', 'gov', 'net', 'com', 'me', 'org', 'apple', 'gov', 'hu', 'gov', 'me', 'me', 'net', 'xyz', 'apple', 'hu', 'org', 'org', 'tech', 'me', 'apple', 'hu', 'apple', 'hu', 'tech', 'net', 'me', 'xyz', 'io', 'tech', 'io', 'apple', 'io', 'apple', 'io', 'net', 'org', 'gov', 'apple', 'hu', 'com', 'io', 'org', 'hu', 'tech', 'io', 'xyz', 'org', 'io', 'net', 'net', 'tech', 'xyz', 'me', 'gov', 'org', 'tech', 'io', 'tech', 'me', 'xyz', 'com', 'hu', 'net', 'com', 'tech', 'org', 'tech', 'apple', 'me', 'net', 'hu', 'hu', 'io', 'apple', 'tech', 'xyz', 'org', 'tech', 'net', 'apple', 'hu', 'apple', 'apple', 'xyz', 'com', 'gov', 'me', 'hu', 'me', 'net', 'apple', 'com', 'apple', 'org', 'com', 'com', 'hu', 'com', 'tech', 'com', 'com', 'hu', 'apple', 'gov', 'io', 'tech', 'net', 'xyz', 'xyz', 'io', 'io', 'hu', 'xyz', 'apple', 'xyz', 'org', 'me', 'net', 'apple', 'io', 'me', 'hu', 'hu', 'io', 'me', 'me', 'org', 'com', 'xyz', 'io', 'xyz', 'com', 'hu', 'hu', 'apple', 'com', 'gov', 'tech', 'tech', 'me', 'xyz', 'com', 'gov', 'gov', 'hu', 'xyz', 'tech', 'com', 'apple', 'apple', 'hu', 'net', 'org', 'net', 'io', 'hu', 'com', 'hu', 'tech', 'apple', 'net', 'apple', 'ap ...

# %% [markdown]
# **12. Another way of doing things.**

# %%
mail = "audrey.boulevart@benextcomapgny.com"
splitMail = mail.replace(".", " ").split("@").copy()

firstName = []
name = []
ope = []
zone = []

firstName.append(splitMail[0].split()[0])
name.append(splitMail[0].split()[-1])
ope.append(splitMail[1].split()[0])
zone.append(splitMail[1].split()[-1])

firstName, name, ope, zone
# Out:
# (['audrey'], ['boulevart'], ['benextcomapgny'], ['com'])

# %%
last_name = []
first_name = []
operator = []
zone = []

list_mail = open("./data/mail.txt","r")
read=list_mail.readlines()

for line in read:
        splitMail = line.replace(".", " ").replace("_", " ").replace("-", " ").split("@").copy()
        #splitMail = line.replace(".", " ").split("@").copy()
        last_name.append(splitMail[0].split()[0])
        first_name.append(splitMail[0].split()[-1])
        operator.append(splitMail[1].split()[0])
        zone.append(splitMail[1].split()[-1])

last_name, first_name, operator, zone
#print(len(first_name))
# Out:
# (['vogal',
#   'aikin',
#   'moore',
#   'halknutson',
#   'alexnorquist',
#   'matthewlulloff',
#   'jenson',
#   'mark4451',
#   'monte',
#   'dan80',
#   'schmitt',
#   'knutsondan',
#   'lepage',
#   'chapman',
#   'upson1544',
#   '552966959',
#   'soloman',
#   'ortiz',
#   'ashwoon',
#   'pettigrew',
#   'doranedward',
#   'mills',
#   'valente',
#   'yang',
#   'ike',
#   'hankshaffer',
#   'larrytrebil',
#   'davis',
#   'davidsonhal',
#   'john8733',
#   'johnfletcher',
#   'cataldi',
#   'rogerfietzer',
#   'edward4185',
#   'hancock',
#   'solberg',
#   'vader',
#   'georgepak',
#   'caswell',
#   'ike',
#   'tapia',
#   '795419860',
#   'chambers',
#   'jack',
#   'joe',
#   'reyesaaron',
#   'ben',
#   'pettigrewgeorge',
#   'miller',
#   'linde',
#   'boyd',
#   'yocum',
#   'davidferro',
#   'george59',
#   'johnsen2201',
#   'thompson',
#   'schutzlarry',
#   'quizoz',
#   'matthew8227',
#   'alex',
#   'georgemoody',
#   'lawicki589',
#   'doran7947',
#   'baueraaron',
#   'mark',
#   'waltermartin',
#   'kaskel',
#   'roberts',
#   'george',
#   'ferry',
#   'fred',
#   'jurgensonpeter',
#   'stevefietzer',
#   'sonderling',
#   'johnsen',
#   'mccormack',
#   'roberts',
#   'valente',
#   'ory',
#   'tyirwin',
#   'paulferry',
#   'george',
#   'frank',
#   'ripka6596',
#   'wagner',
#   'mccormack',
#   '851886792',
#   'zeaser',
#   'adam',
#   'tisler',
#   'ferro',
#   'reardon',
#   'severson',
#   'otto',
#   'illingsworth',
#   'danfletcher',
#   'alex685',
#   'hancock',
#   'carl7884',
#   'paul9581',
#   'sawyer',
#   'johnsen',
#   'aaron',
#   'schiebel2392',
#   'mccormackedward',
#   'tapia1876',
#   'quizoz9628',
#   'rogerstahl',
#   'schutz',
#   'schutz',
#   'carlupson',
#   'larry349',
#   'matthew',
#   'mcginnis',
#   'kalleg',
#   'nugent',
#   'wagle',
#   'chapmannathan',
#   'christensen',
#   'hal536',
#   '472510707',
#   'thomas',
#   'adamillingsworth',
#   'weiss',
#   'peterstahl',
#   'victortandy',
#   'fredturco',
#   'adam',
#   'vader',
#   'ike3831',
#   'timfletcher',
#   'frank',
#   '566486749',
#   '675340599',
#   'davis',
#   '253159777',
#   'edwardschutz',
#   'sagar',
#   '331837931',
#   'aaronbongard',
#   'ty9516',
#   'fred',
#   'schustersteve',
#   'moody',
#   'soloman',
#   'victor630',
#   'yang',
#   'hoffman',
#   'ripka',
#   'vader',
#   'ottochambers',
#   'tylulloff',
#   '263935905',
#   'carlvail',
#   'hanktisler',
#   'uddin1510',
#   'mccormack',
#   'vader',
#   'nelsonmark',
#   'adamvan',
#   'ziegler',
#   'uflan',
#   'sawyer',
#   'dan6858',
#   'stahl',
#   'timirwin',
#   'davis9134',
#   'benuflan',
#   'davidziegler',
#   'carl1959',
#   'alexkeller',
#   'ostranderjoe',
#   '469322116',
#   'monte7207',
#   'lawicki',
#   'fredtiernan',
#   'fietzer',
#   'benquinn',
#   'matthew8594',
#   'hal',
#   'sweeney',
#   'fletcher',
#   'adamkalleg',
#   'woothomas',
#   'thomasdavidson',
#   'moore3490',
#   'walter',
#   'ventotla',
#   'dinkins',
#   '950099319',
#   'roger',
#   'tim',
#   'sawyer',
#   'ben',
#   'carlmills',
#   'markboyd',
#   'johnyocum',
#   '887934540',
#   'ortizjack',
#   'tiernan4456',
#   'roberts',
#   'soloman8370',
#   'alex3716',
#   'tim',
#   'thompson85',
#   'reyes',
#   'resnick',
#   'dinkinsroger',
#   'mills9634',
#   '821464747',
#   'valente',
#   'schiebel1467',
#   'larryschiebel',
#   'adamostrander',
#   'jagtap',
#   'edward',
#   'matthewcataldi',
#   'resnick',
#   'zeller',
#   'trebil',
#   'duffman',
#   'ottoortiz',
#   'david',
#   'delorenzo',
#   'miller',
#   'illingsworth',
#   'nelson',
#   'rogers',
#   'fredwagner',
#   'tyresnick',
#   'hal',
#   'tiernan6950',
#   'schuster',
#   'mills',
#   'casal',
#   'roger',
#   'stevevader',
#   'hankupson',
#   '184536366',
#   'irwin',
#   'napier',
#   'edward',
#   'fletcher',
#   'chambers',
#   'rogers',
#   'tapia',
#   'uddin',
#   'bongardroger',
#   'victor',
#   'ty',
#   'paultiernan',
#   'roger836',
#   'pettigrew',
#   'steve',
#   'johnsen4863',
#   'soloman',
#   '34658710',
#   'cannon',
#   '284857146',
#   '890280316',
#   'kalleg',
#   'weinstein',
#   'alexschmitt',
#   'dan',
#   'steve',
#   'matthewfrick',
#   '237336989',
#   'larry6016',
#   'otto5489',
#   'bongard',
#   '169102677',
#   'upson',
#   'hal',
#   'lepage',
#   'sonderling',
#   '430581778',
#   'walterkassing',
#   'victorceledon',
#   'hesch',
#   'kassing',
#   'duffman6005',
#   'frank',
#   'uddinotto',
#   '703979481',
#   'paul',
#   'nugent',
#   'alex',
#   'aaronsweeney',
#   'knutson',
#   'tydoran',
#   'millerhal',
#   'adamnuttle',
#   'ashwoon8609',
#   'victormiller',
#   'mcginnis',
#   'ramachandran',
#   'monteshaffer',
#   'monte',
#   'pettigrew9750',
#   'yocum',
#   'yocum',
#   'darnell8483',
#   'zeller',
#   'pettigrewlarry',
#   'yocum8146',
#   'ben5039',
#   'mcginnis',
#   'roger',
#   'adamtisler',
#   'matthew3420',
#   'john8770',
#   'hesch',
#   'christensen',
#   'walter',
#   'ben8671',
#   'frankjagtap',
#   'peternuttle',
#   'victor8847',
#   'ferry',
#   '690377034',
#   'lepageroger',
#   'john',
#   'valente',
#   '4709006',
#   'deitz',
#   'fietzer',
#   'kaskel5284',
#   'davidson',
#   'cataldi',
#   'hanktiernan',
#   'ripka2474',
#   'cataldi',
#   'lewis',
#   'matthewmccord',
#   'turco8476',
#   'steve6967',
#   'ortiz',
#   'irwincarl',
#   'wakefieldjoe',
#   'nathansagar',
#   'hydinger',
#   'frank',
#   'fred',
#   'schuster5868',
#   'rogerschwager',
#   '163622426',
#   'baxstercarl',
#   'yang',
#   'aikin',
#   'ortiz',
#   'tisler',
#   'stahl',
#   'aaron',
#   '573168868',
#   'monte1021',
#   'petermccord',
#   'quizoz',
#   'vail',
#   'thomassonderling',
#   'frankaikin',
#   'aaronillingsworth',
#   '859491337',
#   'paul',
#   'waltertisler',
#   'ferro',
#   'george',
#   'timorwig',
#   'jones',
#   'hoffman',
#   'ashwoon',
#   'matthew',
#   'larry2207',
#   'rice',
#   'nuttleben',
#   'dewalt',
#   'ikekassing',
#   '240044289',
#   'otto',
#   'ferro',
#   'hankanderson',
#   'deitz',
#   'turco',
#   'dan',
#   'orwig',
#   'bencaswell',
#   'chambers',
#   'sweeney',
#   '579081959',
#   'moore',
#   'thomas',
#   'darnell',
#   'orwig',
#   'haworth',
#   'nathankalleg',
#   'hal',
#   'yocum',
#   'robertsalex',
#   'alex9835',
#   'roberts',
#   'nathanripka',
#   'sonderling',
#   'matthew',
#   'monte2098',
#   'victor',
#   'cataldi',
#   '822140569',
#   'joe',
#   'matthew',
#   'walter',
#   'baxster',
#   'schickowski',
#   'moody',
#   'yocum',
#   'vader',
#   'schutz',
#   'orwig',
#   'roger7781',
#   'dugan',
#   'lulloff',
#   'vader',
#   'otto',
#   'sawyer',
#   'george',
#   'anderson',
#   'hydinger',
#   'monte',
#   'severson',
#   'jack',
#   'jurgensonpaul',
#   '438861443',
#   'aaron',
#   'fletcher',
#   'weiss2334',
#   'eastman',
#   'doran',
#   'sweeney',
#   'vogal9413',
#   'celedon',
#   'vader',
#   '873166067',
#   'ben',
#   'carl',
#   '421931320',
#   'cataldi',
#   'vogal',
#   '290273746',
#   'tybauer',
#   'larrymyers',
#   'soloman',
#   'rice',
#   'orymonte',
#   'mcginnis',
#   'nathanhancock',
#   'lawless',
#   'paulkassing',
#   'fredroot',
#   'hesch',
#   'napier3011',
#   'napier',
#   'tynapier',
#   'ty3947',
#   'ben',
#   'resnickmonte',
#   'sawyer',
#   'kaskel',
#   'schwager9365',
#   'aaronlewis',
#   'nelson',
#   'upson1390',
#   '871781143',
#   '269062053',
#   'victorreardon',
#   'soloman',
#   'aaronsagar',
#   'alex',
#   'van',
#   'ike5340',
#   '120987413',
#   'ziegler',
#   'van',
#   'tisler',
#   'van',
#   'victorquinn',
#   'lulloffhal',
#   'aaronebner',
#   'fred',
#   'adam3605',
#   'thompson',
#   'stevewagle',
#   'montedeitz',
#   'vanderpoel',
#   'orwig',
#   'roger',
#   'edwarddeitz',
#   '273554425',
#   'edward',
#   'marknapier',
#   'paul635',
#   'upson',
#   'john',
#   'duffman',
#   'jenson',
#   'rogermcginnis',
#   'soukup',
#   'soloman',
#   '877692701',
#   'tandyaaron',
#   'ingramthomas',
#   'aaron8129',
#   'vanderpoeljoe',
#   'fredmills',
#   'haljagtap',
#   'larry',
#   'soloman',
#   'montelewis',
#   '631338425',
#   'peter',
#   'hylan',
#   'roger',
#   'paiser',
#   'schickowski',
#   'ty',
#   'roberts',
#   '958642438',
#   'boyd3853',
#   'soloman',
#   '92101346',
#   'chambers',
#   'nuttleedward',
#   'adamrice',
#   'fred937',
#   'ben',
#   'lepagemark',
#   'dan',
#   'walterturco',
#   'ebner',
#   'danwagner',
#   'jones206',
#   'steve',
#   'roger',
#   'casal',
#   'adamziegler',
#   '275056493',
#   'peterlewis',
#   'jack',
#   'george3788',
#   'seversonpaul',
#   'zeller',
#   'ottoschmitt',
#   'fietzer',
#   'tiernan',
#   'schutz',
#   'matthew2395',
#   'hal',
#   'reyes',
#   'mccord',
#   'uddin2208',
#   'moody1342',
#   'roger6727',
#   'schlicht670',
#   'steve',
#   'sawyer',
#   'soulis2863',
#   'yates',
#   'sonderling4257',
#   'upson',
#   'timtrebil',
#   '104036307',
#   'frankupson',
#   'fietzeralex',
#   'solomanjohn',
#   'peter6564',
#   'johnsen2199',
#   'uflan',
#   'lepage',
#   'dugelman8872',
#   'carlvanderpoel',
#   'vanderpoel',
#   'ripka2789',
#   'chambers',
#   'nathan2454',
#   'larry1596',
#   'moorety',
#   'roger',
#   'soulispeter',
#   'victorschmitt',
#   'ty3503',
#   'lepage',
#   'vanderpoel',
#   'darnellty',
#   'kalleg',
#   'steve',
#   'lulloff',
#   'chamberspaul',
#   'anderson845',
#   'quizoz',
#   'bencasal',
#   'vader',
#   'mark',
#   'lepage6698',
#   'zeller',
#   'walterschwager',
#   'christensenty',
#   'severson',
#   'vailjoe',
#   'tiernan',
#   'dewalt',
#   'rogertrebil',
#   'ziegler8928',
#   'duffman',
#   'wakefield',
#   'dugelman',
#   'nugent1331',
#   'frick',
#   'celedon',
#   'ty',
#   'schmitt',
#   'aaronwagle',
#   'woo',
#   'tim9542',
#   'john5694',
#   'sagar',
#   'larry',
#   'severson',
#   'fredturco',
#   'victoringram',
#   'edward',
#   'tisler',
#   'reyes',
#   'reamer',
#   'schlicht',
#   'steve3131',
#   'wagner9136',
#   'davis',
#   'edward9079',
#   '283141330',
#   'tyduffman',
#   'walterhydinger',
#   'ben9635',
#   'vanderpoel',
#   'delorenzo',
#   'chapman',
#   'nathan',
#   'victorvader',
#   'bateman1522',
#   'ben',
#   'fredhaworth',
#   'eastman',
#   'sweeney',
#   'hydinger',
#   'peter2600',
#   'eastman',
#   'thomas',
#   'hal',
#   'paulresnick',
#   '682804922',
#   'ziegler',
#   'maki',
#   'myerspeter',
#   'fred67',
#   'edwardhoffman',
#   'nuttle',
#   'thompson',
#   'ike',
#   'markhoffman',
#   '669214282',
#   'hank',
#   'pettigrew',
#   'nuttle',
#   'vader',
#   'danziegler',
#   'nugent',
#   'alex',
#   'larry',
#   'aaron735',
#   'deitzdan',
#   'alexhesch',
#   'dinkinscarl',
#   'aaronschwager',
#   'edward',
#   'ory',
#   'dugelman',
#   '43720854',
#   'larryulrich',
#   'tiernanotto',
#   'christensen',
#   '220923632',
#   'stahl',
#   'vader',
#   'lepage',
#   'woofrank',
#   '413352781',
#   'walterschutz',
#   'ike',
#   'tislerjohn',
#   'ebner',
#   'jurgenson',
#   '40053022',
#   'nathanhylan',
#   'carl1266',
#   'ortiz',
#   'johnsen1400',
#   'irwin',
#   'ikechapman',
#   'walter',
#   'nathan',
#   'joeuddin',
#   'lawicki',
#   'casal9156',
#   'resnick2754',
#   'ashwoon',
#   'jack3740',
#   'hal',
#   'jurgenson',
#   '393543398',
#   'steve5769',
#   'duffman',
#   'ramachandran1712',
#   'dugelman',
#   '735354722',
#   'monteschiebel',
#   'larry',
#   'lepage',
#   'duffmanedward',
#   'tim',
#   'schickowski',
#   'steve',
#   'duffman',
#   'rogersty',
#   'paulchapman',
#   'adam',
#   'bongardben',
#   'knutson',
#   'ory',
#   'chambers',
#   'cannon',
#   'rice',
#   '579097737',
#   'chambers',
#   'pettigrewfred',
#   'victorillingsworth',
#   'wagnercarl',
#   'illingsworth',
#   'fred',
#   'tapiajohn',
#   'christensen',
#   'vail',
#   'nathan',
#   'tandy',
#   'victorjones',
#   'resnick',
#   'roger',
#   'resnick',
#   'soukup',
#   'hank',
#   'victorfletcher',
#   'schwager',
#   'weinsteintim',
#   'fred2414',
#   'hesch1648',
#   'weiss',
#   'ottoreamer',
#   'carl',
#   'fietzer',
#   'timbauer',
#   'ike',
#   'matthew',
#   'reardon',
#   'mccormack7946',
#   'matthew6993',
#   'nelson',
#   'peter',
#   'delorenzo',
#   'mcginnis',
#   'edward3639',
#   'mark2192',
#   'dan',
#   'nuttlety',
#   'victortisler',
#   'tisler',
#   'otto',
#   'jacksolberg',
#   'nathan',
#   'fletcher',
#   'dugan',
#   'anderson',
#   'adampak',
#   'peter',
#   'yang',
#   'alex7627',
#   'ben',
#   'ferry',
#   'weiss9401',
#   'haworth',
#   'ulrich9331',
#   'baxster',
#   'dugelman2727',
#   'yates',
#   'otto1543',
#   'bateman',
#   'larryhoffman',
#   'celedonmatthew',
#   'victorrogers',
#   'ashwoon',
#   'van',
#   '711978855',
#   'delorenzo',
#   'zeller',
#   'olson',
#   'aaronmiller',
#   'bensoukup',
#   'sweeneytim',
#   'joe',
#   'doran',
#   'otto',
#   'frankchristensen',
#   '524504262',
#   'tim3793',
#   'otto815',
#   'sweeney',
#   'knutson',
#   'hank',
#   'kalleg',
#   'ikecast',
#   'jack',
#   'myers',
#   'victor',
#   'hancockcarl',
#   'schlicht',
#   'tisler3297',
#   'steve6502',
#   'frank5506',
#   'schwager',
#   'dugelman',
#   'weiss5261',
#   'dantrusela',
#   'leisinger',
#   'roger4965',
#   'mccormack',
#   'jackortiz',
#   'walter',
#   'ferro',
#   'ikemyers',
#   'schmitt',
#   'yates',
#   'schutzike',
#   'upson',
#   'schlicht',
#   'upson',
#   '525072400',
#   'jurgenson',
#   'georgeturco',
#   'hank5891',
#   'weiss',
#   'jenson9642',
#   'thomascaswell',
#   'thomaskalleg',
#   'bowers',
#   'victorresnick',
#   'walter8082',
#   'sellon',
#   'peter',
#   'victor2700',
#   'deitz',
#   '38460014',
#   'hesch',
#   'frankwoo',
#   'van',
#   'ulrich',
#   'adam',
#   'hoffman',
#   'zellersteve',
#   'jonesthomas',
#   'jagtap',
#   'reyes3325',
#   'schickowski7190',
#   'irwin',
#   'moore',
#   'tisler',
#   'thomas',
#   'alexcataldi',
#   'tim',
#   'hankulrich',
#   'otto',
#   'rogerchambers',
#   'alexdavidson',
#   'peter',
#   'ben',
#   'davidson',
#   'jacksellon',
#   'cataldiedward',
#   'sellon',
#   '748522766',
#   'victorsweeney',
#   'nelson',
#   'johnmoody',
#   'peter',
#   'montelulloff',
#   'andersonhal',
#   'napier',
#   'moodygeorge',
#   'peter4809',
#   'marknapier',
#   'darnell',
#   'george',
#   'tim',
#   'pak',
#   'georgecasal',
#   'trusela',
#   'thomasvan',
#   'fred',
#   'alex',
#   'dan',
#   'dewalt',
#   'celedon',
#   'ty8684',
#   'nuttle',
#   'hal',
#   '821663824',
#   'mccord',
#   'orwig',
#   '857071926',
#   'turcolarry',
#   'mcginnis',
#   'johnpettigrew',
#   'root',
#   'hal',
#   'monteschuster',
#   'fietzer',
#   '271794997',
#   'hancock',
#   'wagle',
#   '558791202',
#   'woo',
#   'quinn1097',
#   'sawyer',
#   'trebil5339',
#   'norquist',
#   'ory7664',
#   'olsonjohn',
#   'orwigfrank',
#   'alexfrick',
#   'knutson',
#   'aikin7996',
#   'dewalt674',
#   'ventotla',
#   'ike',
#   'yates',
#   'dan9881',
#   'resnick',
#   'roger',
#   'pak',
#   'edward',
#   'markmoore',
#   'schickowski',
#   'larrysandstrom',
#   'nathan',
#   'fredolson',
#   'nathan',
#   'nelson',
#   'adameastman',
#   'solberg',
#   'carl',
#   'benwoo',
#   'trussel',
#   'vader',
#   'davidashwoon',
#   'sawyer',
#   'rogerbateman',
#   'dinkins',
#   'resnick',
#   'rogercannon',
#   'ebner',
#   'aaron',
#   'halduffman',
#   'celedon',
#   'rogerhoffman',
#   'victor2949',
#   'matthew',
#   'dan9862',
#   'lawicki',
#   'tislertim',
#   'victor3334',
#   'alex',
#   'peter',
#   'trebil',
#   '786331264',
#   'tyjohnson',
#   'valente5120',
#   'joesawyer',
#   'zeller',
#   '187630443',
#   '926609635',
#   'john',
#   'myers6475',
#   'ortiz8400',
#   'sandstromgeorge',
#   'hylan',
#   'adammccord',
#   'jackjenson',
#   ...],
#  ['roger',
#   'joe',
#   'moore',
#   'halknutson',
#   'alexnorquist',
#   'matthewlulloff',
#   'thomas',
#   'mark4451',
#   'hylan',
#   'dan80',
#   'steve',
#   'knutsondan',
#   'lepage',
#   'ben',
#   'upson1544',
#   '552966959',
#   'ziegler',
#   'mark',
#   'hank',
#   'pettigrew',
#   'doranedward',
#   'joe',
#   'alex',
#   'yang',
#   'ike',
#   'hankshaffer',
#   'larrytrebil',
#   'ike',
#   'davidsonhal',
#   'john8733',
#   'johnfletcher',
#   'larry',
#   'rogerfietzer',
#   'edward4185',
#   'matthew',
#   'cast',
#   'jack',
#   'georgepak',
#   'hal',
#   'ike',
#   'quinn',
#   '795419860',
#   'johnsen',
#   'jack',
#   'joe',
#   'reyesaaron',
#   'yang',
#   'pettigrewgeorge',
#   'peter',
#   'carl',
#   'carl',
#   'mark',
#   'davidferro',
#   'george59',
#   'johnsen2201',
#   'adam',
#   'schutzlarry',
#   'joe',
#   'matthew8227',
#   'alex',
#   'georgemoody',
#   'lawicki589',
#   'doran7947',
#   'baueraaron',
#   'mark',
#   'waltermartin',
#   'kaskel',
#   'matthew',
#   'george',
#   'victor',
#   'weiss',
#   'jurgensonpeter',
#   'stevefietzer',
#   'caswell',
#   'walter',
#   'mccormack',
#   'hank',
#   'valente',
#   'walter',
#   'tyirwin',
#   'paulferry',
#   'george',
#   'lulloff',
#   'ripka6596',
#   'schuster',
#   'carl',
#   '851886792',
#   'aaron',
#   'adam',
#   'roger',
#   'dan',
#   'alex',
#   'george',
#   'nuttle',
#   'illingsworth',
#   'danfletcher',
#   'alex685',
#   'valente',
#   'carl7884',
#   'paul9581',
#   'chambers',
#   'tim',
#   'roberts',
#   'schiebel2392',
#   'mccormackedward',
#   'tapia1876',
#   'quizoz9628',
#   'rogerstahl',
#   'johnsen',
#   'monte',
#   'carlupson',
#   'larry349',
#   'linde',
#   'mcginnis',
#   'monte',
#   'jack',
#   'john',
#   'chapmannathan',
#   'larry',
#   'hal536',
#   '472510707',
#   'casal',
#   'adamillingsworth',
#   'adam',
#   'peterstahl',
#   'victortandy',
#   'fredturco',
#   'sellon',
#   'matthew',
#   'ike3831',
#   'timfletcher',
#   'schickowski',
#   '566486749',
#   '675340599',
#   'nathan',
#   '253159777',
#   'edwardschutz',
#   'carl',
#   '331837931',
#   'aaronbongard',
#   'ty9516',
#   'fred',
#   'schustersteve',
#   'schiebel',
#   'ramachandran',
#   'victor630',
#   'trebil',
#   'zeller',
#   'thomas',
#   'hal',
#   'ottochambers',
#   'tylulloff',
#   '263935905',
#   'carlvail',
#   'hanktisler',
#   'uddin1510',
#   'carl',
#   'vader',
#   'nelsonmark',
#   'zandt',
#   'dan',
#   'uflan',
#   'frank',
#   'dan6858',
#   'stahl',
#   'timirwin',
#   'davis9134',
#   'benuflan',
#   'davidziegler',
#   'carl1959',
#   'alexkeller',
#   'ostranderjoe',
#   '469322116',
#   'monte7207',
#   'lawicki',
#   'fredtiernan',
#   'fietzer',
#   'benquinn',
#   'matthew8594',
#   'weiss',
#   'otto',
#   'monte',
#   'adamkalleg',
#   'woothomas',
#   'thomasdavidson',
#   'moore3490',
#   'walter',
#   'alex',
#   'dinkins',
#   '950099319',
#   'myers',
#   'trusela',
#   'adam',
#   'jagtap',
#   'carlmills',
#   'markboyd',
#   'johnyocum',
#   '887934540',
#   'ortizjack',
#   'tiernan4456',
#   'myers',
#   'soloman8370',
#   'alex3716',
#   'tim',
#   'thompson85',
#   'jack',
#   'resnick',
#   'dinkinsroger',
#   'mills9634',
#   '821464747',
#   'hydinger',
#   'schiebel1467',
#   'larryschiebel',
#   'adamostrander',
#   'fred',
#   'haworth',
#   'matthewcataldi',
#   'moore',
#   'zeller',
#   'george',
#   'duffman',
#   'ottoortiz',
#   'rice',
#   'delorenzo',
#   'keller',
#   'illingsworth',
#   'nelson',
#   'john',
#   'fredwagner',
#   'tyresnick',
#   'yang',
#   'tiernan6950',
#   'john',
#   'mills',
#   'hank',
#   'zandt',
#   'stevevader',
#   'hankupson',
#   '184536366',
#   'yang',
#   'aaron',
#   'schickowski',
#   'alex',
#   'monte',
#   'lawicki',
#   'upson',
#   'yocum',
#   'bongardroger',
#   'victor',
#   'schwager',
#   'paultiernan',
#   'roger836',
#   'victor',
#   'ingram',
#   'johnsen4863',
#   'roger',
#   '34658710',
#   'joe',
#   '284857146',
#   '890280316',
#   'joe',
#   'roger',
#   'alexschmitt',
#   'uddin',
#   'stahl',
#   'matthewfrick',
#   '237336989',
#   'larry6016',
#   'otto5489',
#   'ty',
#   '169102677',
#   'hal',
#   'hal',
#   'aaron',
#   'mark',
#   '430581778',
#   'walterkassing',
#   'victorceledon',
#   'john',
#   'kassing',
#   'duffman6005',
#   'ventotla',
#   'uddinotto',
#   '703979481',
#   'nugent',
#   'nugent',
#   'alex',
#   'aaronsweeney',
#   'celedon',
#   'tydoran',
#   'millerhal',
#   'adamnuttle',
#   'ashwoon8609',
#   'victormiller',
#   'reardon',
#   'mark',
#   'monteshaffer',
#   'monte',
#   'pettigrew9750',
#   'dan',
#   'victor',
#   'darnell8483',
#   'matthew',
#   'pettigrewlarry',
#   'yocum8146',
#   'ben5039',
#   'dan',
#   'vogal',
#   'adamtisler',
#   'matthew3420',
#   'john8770',
#   'zeller',
#   'ben',
#   'soulis',
#   'ben8671',
#   'frankjagtap',
#   'peternuttle',
#   'victor8847',
#   'paul',
#   '690377034',
#   'lepageroger',
#   'zeaser',
#   'jack',
#   '4709006',
#   'monte',
#   'frank',
#   'kaskel5284',
#   'monte',
#   'ingram',
#   'hanktiernan',
#   'ripka2474',
#   'matthew',
#   'lulloff',
#   'matthewmccord',
#   'turco8476',
#   'steve6967',
#   'larry',
#   'irwincarl',
#   'wakefieldjoe',
#   'nathansagar',
#   'larry',
#   'yates',
#   'fred',
#   'schuster5868',
#   'rogerschwager',
#   '163622426',
#   'baxstercarl',
#   'hal',
#   'aikin',
#   'david',
#   'reyes',
#   'thomas',
#   'trusela',
#   '573168868',
#   'monte1021',
#   'petermccord',
#   'quizoz',
#   'soukup',
#   'thomassonderling',
#   'frankaikin',
#   'aaronillingsworth',
#   '859491337',
#   'eastman',
#   'waltertisler',
#   'caswell',
#   'george',
#   'timorwig',
#   'jones',
#   'roger',
#   'ashwoon',
#   'trusela',
#   'larry2207',
#   'sonderling',
#   'nuttleben',
#   'martin',
#   'ikekassing',
#   '240044289',
#   'otto',
#   'edward',
#   'hankanderson',
#   'roger',
#   'ike',
#   'deitz',
#   'sweeney',
#   'bencaswell',
#   'victor',
#   'david',
#   '579081959',
#   'fred',
#   'thomas',
#   'otto',
#   'orwig',
#   'john',
#   'nathankalleg',
#   'hal',
#   'yocum',
#   'robertsalex',
#   'alex9835',
#   'hank',
#   'nathanripka',
#   'sonderling',
#   'duffman',
#   'monte2098',
#   'tiernan',
#   'john',
#   '822140569',
#   'joe',
#   'matthew',
#   'walter',
#   'zeaser',
#   'hal',
#   'alex',
#   'ventotla',
#   'sweeney',
#   'schutz',
#   'mills',
#   'roger7781',
#   'thomas',
#   'lulloff',
#   'vader',
#   'otto',
#   'johnson',
#   'george',
#   'john',
#   'aaron',
#   'monte',
#   'aaron',
#   'fletcher',
#   'jurgensonpaul',
#   '438861443',
#   'aaron',
#   'thompson',
#   'weiss2334',
#   'ty',
#   'doran',
#   'nathan',
#   'vogal9413',
#   'bauer',
#   'victor',
#   '873166067',
#   'bongard',
#   'weiss',
#   '421931320',
#   'haworth',
#   'carl',
#   '290273746',
#   'tybauer',
#   'larrymyers',
#   'jack',
#   'mark',
#   'orymonte',
#   'tim',
#   'nathanhancock',
#   'fred',
#   'paulkassing',
#   'fredroot',
#   'ty',
#   'napier3011',
#   'ortiz',
#   'tynapier',
#   'ty3947',
#   'ben',
#   'resnickmonte',
#   'sawyer',
#   'peter',
#   'schwager9365',
#   'aaronlewis',
#   'jack',
#   'upson1390',
#   '871781143',
#   '269062053',
#   'victorreardon',
#   'soloman',
#   'aaronsagar',
#   'alex',
#   'zandt2300',
#   'ike5340',
#   '120987413',
#   'ziegler',
#   'zandt',
#   'monte',
#   'zandt8519',
#   'victorquinn',
#   'lulloffhal',
#   'aaronebner',
#   'moore',
#   'adam3605',
#   'thompson',
#   'stevewagle',
#   'montedeitz',
#   'adam',
#   'john',
#   'roger',
#   'edwarddeitz',
#   '273554425',
#   'darnell',
#   'marknapier',
#   'paul635',
#   'peter',
#   'stahl',
#   'aaron',
#   'jenson',
#   'rogermcginnis',
#   'soukup',
#   'soloman',
#   '877692701',
#   'tandyaaron',
#   'ingramthomas',
#   'aaron8129',
#   'vanderpoeljoe',
#   'fredmills',
#   'haljagtap',
#   'hancock',
#   'eastman',
#   'montelewis',
#   '631338425',
#   'mccord',
#   'hylan',
#   'roger',
#   'paiser',
#   'steve',
#   'ty',
#   'roberts',
#   '958642438',
#   'boyd3853',
#   'nathan',
#   '92101346',
#   'mark',
#   'nuttleedward',
#   'adamrice',
#   'fred937',
#   'ben',
#   'lepagemark',
#   'dan',
#   'walterturco',
#   'fred',
#   'danwagner',
#   'jones206',
#   'root',
#   'fletcher',
#   'david',
#   'adamziegler',
#   '275056493',
#   'peterlewis',
#   'jack',
#   'george3788',
#   'seversonpaul',
#   'roger',
#   'ottoschmitt',
#   'cast',
#   'jack',
#   'knutson',
#   'matthew2395',
#   'severson',
#   'paul',
#   'ferry',
#   'uddin2208',
#   'moody1342',
#   'roger6727',
#   'schlicht670',
#   'steve',
#   'sawyer',
#   'soulis2863',
#   'steve',
#   'sonderling4257',
#   'paul',
#   'timtrebil',
#   '104036307',
#   'frankupson',
#   'fietzeralex',
#   'solomanjohn',
#   'peter6564',
#   'johnsen2199',
#   'frank',
#   'edward',
#   'dugelman8872',
#   'carlvanderpoel',
#   'hydinger',
#   'ripka2789',
#   'aaron',
#   'nathan2454',
#   'larry1596',
#   'moorety',
#   'fietzer',
#   'soulispeter',
#   'victorschmitt',
#   'ty3503',
#   'ostrander',
#   'dan',
#   'darnellty',
#   'david',
#   'steve',
#   'matthew',
#   'chamberspaul',
#   'anderson845',
#   'upson',
#   'bencasal',
#   'john',
#   'lepage',
#   'lepage6698',
#   'ziegler',
#   'walterschwager',
#   'christensenty',
#   'woo',
#   'vailjoe',
#   'frank',
#   'adam',
#   'rogertrebil',
#   'ziegler8928',
#   'ben',
#   'edward',
#   'zandt',
#   'nugent1331',
#   'otto',
#   'severson',
#   'tiernan',
#   'schmitt',
#   'aaronwagle',
#   'woo',
#   'tim9542',
#   'john5694',
#   'nathan',
#   'dinkins',
#   'steve',
#   'fredturco',
#   'victoringram',
#   'edward',
#   'matthew',
#   'roger',
#   'tim',
#   'carl',
#   'steve3131',
#   'wagner9136',
#   'bowers',
#   'edward9079',
#   '283141330',
#   'tyduffman',
#   'walterhydinger',
#   'ben9635',
#   'mark',
#   'jack',
#   'roger',
#   'woo',
#   'victorvader',
#   'bateman1522',
#   'irwin',
#   'fredhaworth',
#   'larry',
#   'alex',
#   'otto',
#   'peter2600',
#   'adam',
#   'thomas',
#   'hal',
#   'paulresnick',
#   '682804922',
#   'alex',
#   'frank',
#   'myerspeter',
#   'fred67',
#   'edwardhoffman',
#   'monte',
#   'orwig',
#   'stahl',
#   'markhoffman',
#   '669214282',
#   'hank',
#   'bauer',
#   'upson',
#   'ty',
#   'danziegler',
#   'uddin',
#   'mccormack',
#   'larry',
#   'aaron735',
#   'deitzdan',
#   'alexhesch',
#   'dinkinscarl',
#   'aaronschwager',
#   'edward',
#   'ty',
#   'roger',
#   '43720854',
#   'larryulrich',
#   'tiernanotto',
#   'ben',
#   '220923632',
#   'larry',
#   'larry',
#   'lepage',
#   'woofrank',
#   '413352781',
#   'walterschutz',
#   'ike',
#   'tislerjohn',
#   'chapman',
#   'mark',
#   '40053022',
#   'nathanhylan',
#   'carl1266',
#   'ortiz',
#   'johnsen1400',
#   'otto',
#   'ikechapman',
#   'walter',
#   'zeller',
#   'joeuddin',
#   'lawicki',
#   'casal9156',
#   'resnick2754',
#   'hank',
#   'jack3740',
#   'casal',
#   'dan',
#   '393543398',
#   'steve5769',
#   'vanderpoel',
#   'ramachandran1712',
#   'adam',
#   '735354722',
#   'monteschiebel',
#   'miller',
#   'peter',
#   'duffmanedward',
#   'roberts',
#   'matthew',
#   'steve',
#   'weiss',
#   'rogersty',
#   'paulchapman',
#   'delorenzo',
#   'bongardben',
#   'walter',
#   'joe',
#   'walter',
#   'ferro',
#   'soulis',
#   '579097737',
#   'roberts',
#   'pettigrewfred',
#   'victorillingsworth',
#   'wagnercarl',
#   'roger',
#   'fred',
#   'tapiajohn',
#   'christensen',
#   'vail',
#   'nathan',
#   'tandy',
#   'victorjones',
#   'david',
#   'roger',
#   'thomas',
#   'tim',
#   'hank',
#   'victorfletcher',
#   'pak',
#   'weinsteintim',
#   'fred2414',
#   'hesch1648',
#   'walter',
#   'ottoreamer',
#   'carl',
#   'kaskel',
#   'timbauer',
#   'reyes',
#   'matthew',
#   'reardon',
#   'mccormack7946',
#   'matthew6993',
#   'matthew',
#   'mccormack',
#   'larry',
#   'walter',
#   'edward3639',
#   'mark2192',
#   'dan',
#   'nuttlety',
#   'victortisler',
#   'cannon',
#   'jurgenson',
#   'jacksolberg',
#   'vanderpoel',
#   'duffman',
#   'ortiz',
#   'dewalt',
#   'adampak',
#   'norquist',
#   'yang',
#   'alex7627',
#   'ben',
#   'walter',
#   'weiss9401',
#   'steve',
#   'ulrich9331',
#   'mark',
#   'dugelman2727',
#   'hal',
#   'otto1543',
#   'joe',
#   'larryhoffman',
#   'celedonmatthew',
#   'victorrogers',
#   'ben',
#   'deitz',
#   '711978855',
#   'delorenzo',
#   'john',
#   'olson',
#   'aaronmiller',
#   'bensoukup',
#   'sweeneytim',
#   'joe',
#   'doran',
#   'otto',
#   'frankchristensen',
#   '524504262',
#   'tim3793',
#   'otto815',
#   'carl',
#   'trebil',
#   'nuttle',
#   'tim',
#   'ikecast',
#   'weinstein',
#   'ramachandran',
#   'victor',
#   'hancockcarl',
#   'dan',
#   'tisler3297',
#   'steve6502',
#   'frank5506',
#   'joe',
#   'jack',
#   'weiss5261',
#   'dantrusela',
#   'walter',
#   'roger4965',
#   'ike',
#   'jackortiz',
#   'walter',
#   'peter',
#   'ikemyers',
#   'schmitt',
#   'thomas',
#   'schutzike',
#   'upson',
#   'monte',
#   'upson',
#   '525072400',
#   'trusela',
#   'georgeturco',
#   'hank5891',
#   'hank',
#   'jenson9642',
#   'thomascaswell',
#   'thomaskalleg',
#   'steve',
#   'victorresnick',
#   'walter8082',
#   'roger',
#   'peter',
#   'victor2700',
#   'edward',
#   '38460014',
#   'mills',
#   'frankwoo',
#   'soloman',
#   'carl',
#   'adam',
#   'hoffman',
#   'zellersteve',
#   'jonesthomas',
#   'victor',
#   'reyes3325',
#   'schickowski7190',
#   'irwin',
#   'edward',
#   'fred',
#   'thomas',
#   'alexcataldi',
#   'tim',
#   'hankulrich',
#   'reamer',
#   'rogerchambers',
#   'alexdavidson',
#   'moody',
#   'weinstein',
#   'jack',
#   'jacksellon',
#   'cataldiedward',
#   'jack',
#   '748522766',
#   'victorsweeney',
#   'matthew',
#   'johnmoody',
#   'sandstrom',
#   'montelulloff',
#   'andersonhal',
#   'hank',
#   'moodygeorge',
#   'peter4809',
#   'marknapier',
#   'roger',
#   'george',
#   'weinstein',
#   'roger',
#   'georgecasal',
#   'jack',
#   'zandt',
#   'martin',
#   'alex',
#   'ventotla',
#   'joe',
#   'hesch',
#   'ty8684',
#   'yang',
#   'rice',
#   '821663824',
#   'fred',
#   'orwig',
#   '857071926',
#   'turcolarry',
#   'aaron',
#   'johnpettigrew',
#   'edward',
#   'yocum',
#   'monteschuster',
#   'mark',
#   '271794997',
#   'hancock',
#   'doran',
#   '558791202',
#   'aaron',
#   'quinn1097',
#   'sawyer',
#   'trebil5339',
#   'mark',
#   'ory7664',
#   'olsonjohn',
#   'orwigfrank',
#   'alexfrick',
#   'matthew',
#   'aikin7996',
#   'dewalt674',
#   'haworth',
#   'ike',
#   'hal',
#   'dan9881',
#   'john',
#   'deitz',
#   'matthew',
#   'edward',
#   'markmoore',
#   'roger',
#   'larrysandstrom',
#   'nathan',
#   'fredolson',
#   'rogers',
#   'peter',
#   'adameastman',
#   'solberg',
#   'mcginnis',
#   'benwoo',
#   'moore',
#   'thompson',
#   'davidashwoon',
#   'steve',
#   'rogerbateman',
#   'weinstein',
#   'edward',
#   'rogercannon',
#   'walter',
#   'aaron',
#   'halduffman',
#   'ostrander',
#   'rogerhoffman',
#   'victor2949',
#   'schwager',
#   'dan9862',
#   'carl',
#   'tislertim',
#   'victor3334',
#   'alex',
#   'tisler',
#   'trebil',
#   '786331264',
#   'tyjohnson',
#   'valente5120',
#   'joesawyer',
#   'nathan',
#   '187630443',
#   '926609635',
#   'john',
#   'myers6475',
#   'ortiz8400',
#   'sandstromgeorge',
#   'tandy',
#   'adammccord',
#   'jackjenson',
#   ...],
#  ['mail',
#   'odul',
#   'imail',
#   'email',
#   'proton',
#   'mail',
#   'belgaximus',
#   'mail',
#   'belgaximus',
#   'mail',
#   'napster',
#   'belgaximus',
#   'gaagle',
#   'napster',
#   'youhoo',
#   'belgaximus',
#   'email',
#   'napster',
#   'imail',
#   'proton',
#   'napster',
#   'imail',
#   'mail',
#   'email',
#   'ecoin',
#   'mail',
#   'email',
#   'odul',
#   'hotmoille',
#   'youhoo',
#   'youhoo',
#   'napster',
#   'imail',
#   'gaagle',
#   'belgaximus',
#   'gaagle',
#   'youhoo',
#   'gaagle',
#   'ecoin',
#   'ecoin',
#   'gaagle',
#   'imail',
#   'mail',
#   'gaagle',
#   'ecoin',
#   'mail',
#   'ecoin',
#   'odul',
#   'mail',
#   'belgaximus',
#   'napster',
#   'youhoo',
#   'mail',
#   'ecoin',
#   'imail',
#   'mail',
#   'email',
#   'napster',
#   'hotmoille',
#   'mail',
#   'hotmoille',
#   'hotmoille',
#   'gaagle',
#   'mail',
#   'email',
#   'ecoin',
#   'mail',
#   'mail',
#   'hotmoille',
#   'gaagle',
#   'odul',
#   'proton',
#   'ecoin',
#   'napster',
#   'odul',
#   'napster',
#   'proton',
#   'gaagle',
#   'proton',
#   'proton',
#   'hotmoille',
#   'youhoo',
#   'mail',
#   'mail',
#   'mail',
#   'imail',
#   'youhoo',
#   'belgaximus',
#   'proton',
#   'hotmoille',
#   'proton',
#   'gaagle',
#   'proton',
#   'proton',
#   'belgaximus',
#   'mail',
#   'hotmoille',
#   'hotmoille',
#   'mail',
#   'email',
#   'belgaximus',
#   'email',
#   'imail',
#   'hotmoille',
#   'proton',
#   'imail',
#   'belgaximus',
#   'odul',
#   'ecoin',
#   'hotmoille',
#   'napster',
#   'odul',
#   'youhoo',
#   'imail',
#   'mail',
#   'gaagle',
#   'napster',
#   'youhoo',
#   'hotmoille',
#   'napster',
#   'odul',
#   'hotmoille',
#   'youhoo',
#   'mail',
#   'gaagle',
#   'youhoo',
#   'mail',
#   'email',
#   'belgaximus',
#   'proton',
#   'imail',
#   'gaagle',
#   'email',
#   'proton',
#   'ecoin',
#   'gaagle',
#   'hotmoille',
#   'hotmoille',
#   'napster',
#   'odul',
#   'belgaximus',
#   'mail',
#   'proton',
#   'hotmoille',
#   'gaagle',
#   'hotmoille',
#   'imail',
#   'imail',
#   'email',
#   'belgaximus',
#   'imail',
#   'email',
#   'youhoo',
#   'napster',
#   'ecoin',
#   'email',
#   'proton',
#   'proton',
#   'imail',
#   'belgaximus',
#   'proton',
#   'mail',
#   'ecoin',
#   'mail',
#   'odul',
#   'hotmoille',
#   'imail',
#   'mail',
#   'imail',
#   'youhoo',
#   'gaagle',
#   'mail',
#   'hotmoille',
#   'gaagle',
#   'mail',
#   'email',
#   'gaagle',
#   'proton',
#   'mail',
#   'email',
#   'gaagle',
#   'email',
#   'mail',
#   'napster',
#   'mail',
#   'mail',
#   'napster',
#   'mail',
#   'proton',
#   'imail',
#   'gaagle',
#   'hotmoille',
#   'belgaximus',
#   'napster',
#   'ecoin',
#   'belgaximus',
#   'mail',
#   'email',
#   'gaagle',
#   'mail',
#   'email',
#   'odul',
#   'ecoin',
#   'proton',
#   'proton',
#   'email',
#   'mail',
#   'youhoo',
#   'odul',
#   'odul',
#   'hotmoille',
#   'proton',
#   'ecoin',
#   'mail',
#   'proton',
#   'imail',
#   'youhoo',
#   'mail',
#   'email',
#   'youhoo',
#   'email',
#   'youhoo',
#   'mail',
#   'ecoin',
#   'email',
#   'youhoo',
#   'odul',
#   'gaagle',
#   'mail',
#   'imail',
#   'napster',
#   'belgaximus',
#   'email',
#   'belgaximus',
#   'proton',
#   'gaagle',
#   'mail',
#   'odul',
#   'mail',
#   'gaagle',
#   'email',
#   'youhoo',
#   'imail',
#   'mail',
#   'gaagle',
#   'ecoin',
#   'gaagle',
#   'napster',
#   'youhoo',
#   'napster',
#   'youhoo',
#   'gaagle',
#   'email',
#   'mail',
#   'gaagle',
#   'ecoin',
#   'mail',
#   'mail',
#   'mail',
#   'ecoin',
#   'belgaximus',
#   'imail',
#   'odul',
#   'ecoin',
#   'hotmoille',
#   'hotmoille',
#   'email',
#   'youhoo',
#   'gaagle',
#   'ecoin',
#   'gaagle',
#   'gaagle',
#   'hotmoille',
#   'hotmoille',
#   'belgaximus',
#   'hotmoille',
#   'napster',
#   'ecoin',
#   'odul',
#   'hotmoille',
#   'youhoo',
#   'belgaximus',
#   'youhoo',
#   'ecoin',
#   'ecoin',
#   'proton',
#   'odul',
#   'ecoin',
#   'hotmoille',
#   'belgaximus',
#   'hotmoille',
#   'youhoo',
#   'youhoo',
#   'mail',
#   'youhoo',
#   'proton',
#   'proton',
#   'proton',
#   'proton',
#   'napster',
#   'imail',
#   'email',
#   'ecoin',
#   'imail',
#   'mail',
#   'hotmoille',
#   'gaagle',
#   'email',
#   'gaagle',
#   'hotmoille',
#   'napster',
#   'email',
#   'proton',
#   'email',
#   'proton',
#   'napster',
#   'napster',
#   'ecoin',
#   'imail',
#   'gaagle',
#   'proton',
#   'imail',
#   'gaagle',
#   'napster',
#   'odul',
#   'hotmoille',
#   'belgaximus',
#   'mail',
#   'mail',
#   'youhoo',
#   'hotmoille',
#   'odul',
#   'mail',
#   'mail',
#   'mail',
#   'odul',
#   'napster',
#   'belgaximus',
#   'ecoin',
#   'email',
#   'odul',
#   'proton',
#   'mail',
#   'youhoo',
#   'imail',
#   'imail',
#   'proton',
#   'mail',
#   'napster',
#   'mail',
#   'imail',
#   'mail',
#   'mail',
#   'mail',
#   'hotmoille',
#   'mail',
#   'proton',
#   'proton',
#   'napster',
#   'odul',
#   'hotmoille',
#   'youhoo',
#   'napster',
#   'belgaximus',
#   'hotmoille',
#   'gaagle',
#   'email',
#   'napster',
#   'youhoo',
#   'mail',
#   'imail',
#   'imail',
#   'gaagle',
#   'proton',
#   'belgaximus',
#   'gaagle',
#   'odul',
#   'napster',
#   'imail',
#   'imail',
#   'odul',
#   'mail',
#   'belgaximus',
#   'proton',
#   'youhoo',
#   'email',
#   'mail',
#   'ecoin',
#   'imail',
#   'gaagle',
#   'imail',
#   'imail',
#   'imail',
#   'mail',
#   'imail',
#   'mail',
#   'mail',
#   'email',
#   'hotmoille',
#   'belgaximus',
#   'napster',
#   'gaagle',
#   'odul',
#   'email',
#   'mail',
#   'proton',
#   'hotmoille',
#   'gaagle',
#   'napster',
#   'mail',
#   'proton',
#   'odul',
#   'email',
#   'ecoin',
#   'mail',
#   'youhoo',
#   'odul',
#   'odul',
#   'mail',
#   'gaagle',
#   'gaagle',
#   'hotmoille',
#   'hotmoille',
#   'hotmoille',
#   'ecoin',
#   'hotmoille',
#   'proton',
#   'napster',
#   'ecoin',
#   'ecoin',
#   'proton',
#   'mail',
#   'mail',
#   'belgaximus',
#   'email',
#   'proton',
#   'mail',
#   'gaagle',
#   'mail',
#   'mail',
#   'hotmoille',
#   'mail',
#   'belgaximus',
#   'gaagle',
#   'mail',
#   'hotmoille',
#   'imail',
#   'hotmoille',
#   'imail',
#   'mail',
#   'youhoo',
#   'mail',
#   'mail',
#   'imail',
#   'mail',
#   'odul',
#   'napster',
#   'email',
#   'mail',
#   'napster',
#   'ecoin',
#   'odul',
#   'mail',
#   'imail',
#   'youhoo',
#   'hotmoille',
#   'proton',
#   'gaagle',
#   'proton',
#   'odul',
#   'youhoo',
#   'proton',
#   'gaagle',
#   'ecoin',
#   'odul',
#   'gaagle',
#   'email',
#   'email',
#   'hotmoille',
#   'email',
#   'odul',
#   'odul',
#   'gaagle',
#   'mail',
#   'youhoo',
#   'gaagle',
#   'gaagle',
#   'mail',
#   'napster',
#   'napster',
#   'proton',
#   'email',
#   'napster',
#   'gaagle',
#   'proton',
#   'proton',
#   'youhoo',
#   'mail',
#   'gaagle',
#   'email',
#   'proton',
#   'hotmoille',
#   'napster',
#   'belgaximus',
#   'odul',
#   'napster',
#   'ecoin',
#   'youhoo',
#   'belgaximus',
#   'mail',
#   'imail',
#   'hotmoille',
#   'mail',
#   'email',
#   'gaagle',
#   'mail',
#   'gaagle',
#   'mail',
#   'proton',
#   'youhoo',
#   'belgaximus',
#   'imail',
#   'youhoo',
#   'email',
#   'belgaximus',
#   'youhoo',
#   'proton',
#   'napster',
#   'gaagle',
#   'ecoin',
#   'odul',
#   'belgaximus',
#   'mail',
#   'gaagle',
#   'imail',
#   'mail',
#   'mail',
#   'mail',
#   'mail',
#   'belgaximus',
#   'mail',
#   'youhoo',
#   'youhoo',
#   'belgaximus',
#   'imail',
#   'gaagle',
#   'mail',
#   'youhoo',
#   'odul',
#   'mail',
#   'ecoin',
#   'gaagle',
#   'mail',
#   'youhoo',
#   'imail',
#   'odul',
#   'youhoo',
#   'mail',
#   'imail',
#   'hotmoille',
#   'odul',
#   'napster',
#   'belgaximus',
#   'mail',
#   'email',
#   'gaagle',
#   'belgaximus',
#   'ecoin',
#   'imail',
#   'youhoo',
#   'youhoo',
#   'email',
#   'gaagle',
#   'belgaximus',
#   'ecoin',
#   'odul',
#   'mail',
#   'odul',
#   'email',
#   'mail',
#   'mail',
#   'imail',
#   'napster',
#   'belgaximus',
#   'imail',
#   'mail',
#   'imail',
#   'hotmoille',
#   'gaagle',
#   'gaagle',
#   'belgaximus',
#   'odul',
#   'proton',
#   'odul',
#   'mail',
#   'mail',
#   'odul',
#   'napster',
#   'mail',
#   'email',
#   'ecoin',
#   'email',
#   'napster',
#   'proton',
#   'imail',
#   'napster',
#   'proton',
#   'mail',
#   'imail',
#   'hotmoille',
#   'youhoo',
#   'gaagle',
#   'proton',
#   'hotmoille',
#   'odul',
#   'odul',
#   'imail',
#   'email',
#   'hotmoille',
#   'hotmoille',
#   'email',
#   'belgaximus',
#   'proton',
#   'imail',
#   'odul',
#   'mail',
#   'youhoo',
#   'imail',
#   'ecoin',
#   'hotmoille',
#   'ecoin',
#   'email',
#   'gaagle',
#   'belgaximus',
#   'napster',
#   'gaagle',
#   'hotmoille',
#   'ecoin',
#   'odul',
#   'odul',
#   'napster',
#   'mail',
#   'proton',
#   'belgaximus',
#   'mail',
#   'email',
#   'mail',
#   'napster',
#   'hotmoille',
#   'email',
#   'belgaximus',
#   'imail',
#   'gaagle',
#   'napster',
#   'gaagle',
#   'ecoin',
#   'odul',
#   'mail',
#   'youhoo',
#   'youhoo',
#   'napster',
#   'email',
#   'napster',
#   'hotmoille',
#   'imail',
#   'imail',
#   'proton',
#   'youhoo',
#   'ecoin',
#   'mail',
#   'hotmoille',
#   'belgaximus',
#   'hotmoille',
#   'youhoo',
#   'mail',
#   'imail',
#   'odul',
#   'napster',
#   'mail',
#   'imail',
#   'ecoin',
#   'mail',
#   'ecoin',
#   'mail',
#   'hotmoille',
#   'odul',
#   'proton',
#   'mail',
#   'belgaximus',
#   'odul',
#   'youhoo',
#   'imail',
#   'imail',
#   'proton',
#   'napster',
#   'email',
#   'odul',
#   'belgaximus',
#   'gaagle',
#   'proton',
#   'gaagle',
#   'mail',
#   'proton',
#   'youhoo',
#   'mail',
#   'odul',
#   'ecoin',
#   'gaagle',
#   'belgaximus',
#   'youhoo',
#   'odul',
#   'proton',
#   'hotmoille',
#   'napster',
#   'proton',
#   'proton',
#   'odul',
#   'mail',
#   'imail',
#   'hotmoille',
#   'odul',
#   'youhoo',
#   'hotmoille',
#   'email',
#   'ecoin',
#   'napster',
#   'youhoo',
#   'proton',
#   'hotmoille',
#   'imail',
#   'mail',
#   'napster',
#   'belgaximus',
#   'belgaximus',
#   'ecoin',
#   'ecoin',
#   'ecoin',
#   'belgaximus',
#   'mail',
#   'odul',
#   'ecoin',
#   'proton',
#   'mail',
#   'imail',
#   'mail',
#   'belgaximus',
#   'gaagle',
#   'imail',
#   'mail',
#   'napster',
#   'odul',
#   'proton',
#   'imail',
#   'odul',
#   'hotmoille',
#   'imail',
#   'odul',
#   'proton',
#   'hotmoille',
#   'imail',
#   'gaagle',
#   'email',
#   'mail',
#   'mail',
#   'ecoin',
#   'belgaximus',
#   'hotmoille',
#   'gaagle',
#   'youhoo',
#   'hotmoille',
#   'imail',
#   'mail',
#   'mail',
#   'email',
#   'mail',
#   'youhoo',
#   'hotmoille',
#   'gaagle',
#   'youhoo',
#   'youhoo',
#   'mail',
#   'gaagle',
#   'belgaximus',
#   'ecoin',
#   'hotmoille',
#   'odul',
#   'hotmoille',
#   'napster',
#   'imail',
#   'youhoo',
#   'napster',
#   'imail',
#   'youhoo',
#   'youhoo',
#   'email',
#   'email',
#   'odul',
#   'odul',
#   'youhoo',
#   'odul',
#   'belgaximus',
#   'napster',
#   'gaagle',
#   'napster',
#   'belgaximus',
#   'email',
#   'belgaximus',
#   'napster',
#   'odul',
#   'mail',
#   'proton',
#   'ecoin',
#   'proton',
#   'proton',
#   'hotmoille',
#   'odul',
#   'odul',
#   'gaagle',
#   'email',
#   'gaagle',
#   'email',
#   'mail',
#   'gaagle',
#   'mail',
#   'email',
#   'mail',
#   'proton',
#   'napster',
#   'email',
#   'belgaximus',
#   'email',
#   'imail',
#   'napster',
#   'hotmoille',
#   'email',
#   'odul',
#   'hotmoille',
#   'odul',
#   'youhoo',
#   'imail',
#   'mail',
#   'ecoin',
#   'mail',
#   'imail',
#   'belgaximus',
#   'ecoin',
#   'hotmoille',
#   'hotmoille',
#   'youhoo',
#   'proton',
#   'odul',
#   'imail',
#   'mail',
#   'proton',
#   'proton',
#   'napster',
#   'ecoin',
#   'napster',
#   'proton',
#   'mail',
#   'proton',
#   'hotmoille',
#   'napster',
#   'belgaximus',
#   'mail',
#   'ecoin',
#   'napster',
#   'belgaximus',
#   'belgaximus',
#   'mail',
#   'hotmoille',
#   'napster',
#   'email',
#   'email',
#   'youhoo',
#   'odul',
#   'odul',
#   'youhoo',
#   'imail',
#   'email',
#   'napster',
#   'mail',
#   'belgaximus',
#   'mail',
#   'mail',
#   'mail',
#   'proton',
#   'odul',
#   'youhoo',
#   'napster',
#   'hotmoille',
#   'ecoin',
#   'gaagle',
#   'odul',
#   'belgaximus',
#   'imail',
#   'napster',
#   'email',
#   'odul',
#   'belgaximus',
#   'proton',
#   'email',
#   'proton',
#   'hotmoille',
#   'belgaximus',
#   'odul',
#   'proton',
#   'hotmoille',
#   'email',
#   'email',
#   'youhoo',
#   'proton',
#   'proton',
#   'email',
#   'youhoo',
#   'odul',
#   'youhoo',
#   'napster',
#   'odul',
#   'proton',
#   'ecoin',
#   'mail',
#   'gaagle',
#   'email',
#   'proton',
#   'gaagle',
#   'email',
#   'belgaximus',
#   'gaagle',
#   'imail',
#   'imail',
#   'hotmoille',
#   'napster',
#   'ecoin',
#   'imail',
#   'proton',
#   'mail',
#   'email',
#   'belgaximus',
#   'belgaximus',
#   'mail',
#   'mail',
#   'odul',
#   'belgaximus',
#   'napster',
#   'imail',
#   'ecoin',
#   'odul',
#   'mail',
#   'napster',
#   'gaagle',
#   'gaagle',
#   'odul',
#   'email',
#   'hotmoille',
#   'odul',
#   'napster',
#   'mail',
#   'odul',
#   'proton',
#   'email',
#   'mail',
#   'email',
#   'mail',
#   'mail',
#   'mail',
#   'belgaximus',
#   'imail',
#   'mail',
#   'mail',
#   'mail',
#   'youhoo',
#   'mail',
#   'hotmoille',
#   'mail',
#   'email',
#   'email',
#   'hotmoille',
#   'imail',
#   'ecoin',
#   'gaagle',
#   'mail',
#   'belgaximus',
#   'mail',
#   'mail',
#   'ecoin',
#   'napster',
#   'gaagle',
#   'imail',
#   'mail',
#   'odul',
#   'imail',
#   'odul',
#   'hotmoille',
#   'email',
#   'napster',
#   'hotmoille',
#   'odul',
#   'napster',
#   'mail',
#   ...],
#  ['tech',
#   'xyz',
#   'gov',
#   'xyz',
#   'com',
#   'me',
#   'org',
#   'gov',
#   'net',
#   'com',
#   'org',
#   'org',
#   'xyz',
#   'hu',
#   'hu',
#   'hu',
#   'tech',
#   'me',
#   'io',
#   'hu',
#   'net',
#   'xyz',
#   'net',
#   'hu',
#   'io',
#   'io',
#   'org',
#   'io',
#   'apple',
#   'com',
#   'me',
#   'com',
#   'apple',
#   'gov',
#   'gov',
#   'apple',
#   'hu',
#   'me',
#   'io',
#   'com',
#   'io',
#   'tech',
#   'me',
#   'apple',
#   'tech',
#   'hu',
#   'com',
#   'me',
#   'xyz',
#   'org',
#   'me',
#   'com',
#   'com',
#   'gov',
#   'io',
#   'me',
#   'apple',
#   'tech',
#   'me',
#   'net',
#   'com',
#   'me',
#   'tech',
#   'gov',
#   'io',
#   'gov',
#   'tech',
#   'hu',
#   'hu',
#   'com',
#   'tech',
#   'tech',
#   'tech',
#   'tech',
#   'net',
#   'xyz',
#   'net',
#   'xyz',
#   'hu',
#   'tech',
#   'com',
#   'gov',
#   'apple',
#   'net',
#   'me',
#   'xyz',
#   'hu',
#   'apple',
#   'net',
#   'tech',
#   'io',
#   'tech',
#   'org',
#   'hu',
#   'gov',
#   'net',
#   'com',
#   'net',
#   'apple',
#   'tech',
#   'xyz',
#   'gov',
#   'gov',
#   'xyz',
#   'com',
#   'tech',
#   'apple',
#   'apple',
#   'tech',
#   'net',
#   'me',
#   'me',
#   'tech',
#   'xyz',
#   'com',
#   'hu',
#   'gov',
#   'org',
#   'net',
#   'net',
#   'io',
#   'com',
#   'xyz',
#   'tech',
#   'me',
#   'hu',
#   'hu',
#   'tech',
#   'gov',
#   'apple',
#   'xyz',
#   'io',
#   'net',
#   'org',
#   'com',
#   'net',
#   'net',
#   'org',
#   'me',
#   'xyz',
#   'net',
#   'apple',
#   'tech',
#   'me',
#   'org',
#   'hu',
#   'me',
#   'me',
#   'tech',
#   'org',
#   'io',
#   'gov',
#   'tech',
#   'me',
#   'com',
#   'org',
#   'net',
#   'me',
#   'xyz',
#   'hu',
#   'me',
#   'gov',
#   'net',
#   'io',
#   'apple',
#   'me',
#   'tech',
#   'org',
#   'tech',
#   'apple',
#   'com',
#   'tech',
#   'tech',
#   'hu',
#   'io',
#   'net',
#   'org',
#   'com',
#   'xyz',
#   'xyz',
#   'apple',
#   'com',
#   'hu',
#   'tech',
#   'io',
#   'me',
#   'io',
#   'tech',
#   'gov',
#   'net',
#   'io',
#   'gov',
#   'org',
#   'tech',
#   'me',
#   'apple',
#   'apple',
#   'net',
#   'gov',
#   'xyz',
#   'tech',
#   'gov',
#   'me',
#   'me',
#   'hu',
#   'hu',
#   'hu',
#   'apple',
#   'xyz',
#   'gov',
#   'tech',
#   'io',
#   'net',
#   'gov',
#   'gov',
#   'com',
#   'net',
#   'tech',
#   'org',
#   'apple',
#   'net',
#   'xyz',
#   'org',
#   'me',
#   'org',
#   'gov',
#   'tech',
#   'tech',
#   'org',
#   'io',
#   'xyz',
#   'tech',
#   'tech',
#   'xyz',
#   'xyz',
#   'org',
#   'me',
#   'xyz',
#   'me',
#   'gov',
#   'org',
#   'xyz',
#   'com',
#   'gov',
#   'apple',
#   'me',
#   'hu',
#   'net',
#   'gov',
#   'io',
#   'xyz',
#   'tech',
#   'io',
#   'me',
#   'apple',
#   'apple',
#   'xyz',
#   'io',
#   'net',
#   'me',
#   'com',
#   'io',
#   'org',
#   'apple',
#   'me',
#   'com',
#   'io',
#   'org',
#   'tech',
#   'xyz',
#   'me',
#   'io',
#   'gov',
#   'apple',
#   'me',
#   'com',
#   'tech',
#   'xyz',
#   'io',
#   'apple',
#   'hu',
#   'io',
#   'org',
#   'apple',
#   'apple',
#   'org',
#   'tech',
#   'apple',
#   'xyz',
#   'org',
#   'org',
#   'hu',
#   'tech',
#   'org',
#   'org',
#   'com',
#   'tech',
#   'gov',
#   'com',
#   'xyz',
#   'xyz',
#   'xyz',
#   'apple',
#   'tech',
#   'me',
#   'tech',
#   'tech',
#   'xyz',
#   'xyz',
#   'tech',
#   'hu',
#   'apple',
#   'com',
#   'com',
#   'tech',
#   'com',
#   'gov',
#   'io',
#   'org',
#   'apple',
#   'gov',
#   'gov',
#   'me',
#   'tech',
#   'gov',
#   'tech',
#   'org',
#   'xyz',
#   'tech',
#   'io',
#   'tech',
#   'me',
#   'org',
#   'me',
#   'apple',
#   'hu',
#   'org',
#   'gov',
#   'org',
#   'apple',
#   'xyz',
#   'gov',
#   'apple',
#   'tech',
#   'tech',
#   'com',
#   'net',
#   'net',
#   'gov',
#   'io',
#   'io',
#   'org',
#   'gov',
#   'tech',
#   'gov',
#   'xyz',
#   'apple',
#   'apple',
#   'com',
#   'io',
#   'com',
#   'hu',
#   'io',
#   'apple',
#   'com',
#   'hu',
#   'io',
#   'net',
#   'xyz',
#   'tech',
#   'io',
#   'apple',
#   'hu',
#   'net',
#   'io',
#   'com',
#   'tech',
#   'hu',
#   'xyz',
#   'net',
#   'net',
#   'xyz',
#   'gov',
#   'me',
#   'apple',
#   'net',
#   'hu',
#   'hu',
#   'com',
#   'me',
#   'com',
#   'tech',
#   'org',
#   'xyz',
#   'me',
#   'me',
#   'gov',
#   'org',
#   'hu',
#   'com',
#   'xyz',
#   'net',
#   'io',
#   'hu',
#   'org',
#   'net',
#   'com',
#   'tech',
#   'net',
#   'hu',
#   'apple',
#   'org',
#   'tech',
#   'hu',
#   'hu',
#   'me',
#   'io',
#   'tech',
#   'net',
#   'apple',
#   'xyz',
#   'apple',
#   'net',
#   'gov',
#   'com',
#   'com',
#   'io',
#   'com',
#   'io',
#   'gov',
#   'com',
#   'com',
#   'net',
#   'me',
#   'org',
#   'xyz',
#   'tech',
#   'net',
#   'tech',
#   'net',
#   'com',
#   'me',
#   'gov',
#   'com',
#   'xyz',
#   'me',
#   'apple',
#   'tech',
#   'gov',
#   'me',
#   'me',
#   'xyz',
#   'net',
#   'tech',
#   'gov',
#   'com',
#   'tech',
#   'com',
#   'org',
#   'org',
#   'io',
#   'com',
#   'hu',
#   'com',
#   'tech',
#   'io',
#   'gov',
#   'apple',
#   'apple',
#   'org',
#   'me',
#   'com',
#   'tech',
#   'org',
#   'hu',
#   'xyz',
#   'apple',
#   'tech',
#   'hu',
#   'me',
#   'gov',
#   'me',
#   'io',
#   'net',
#   'apple',
#   'net',
#   'io',
#   'hu',
#   'com',
#   'hu',
#   'gov',
#   'org',
#   'apple',
#   'tech',
#   'gov',
#   'org',
#   'com',
#   'xyz',
#   'me',
#   'xyz',
#   'hu',
#   'hu',
#   'tech',
#   'gov',
#   'apple',
#   'hu',
#   'tech',
#   'xyz',
#   'apple',
#   'io',
#   'net',
#   'org',
#   'xyz',
#   'com',
#   'org',
#   'gov',
#   'com',
#   'apple',
#   'io',
#   'gov',
#   'gov',
#   'gov',
#   'gov',
#   'net',
#   'net',
#   'gov',
#   'tech',
#   'com',
#   'apple',
#   'net',
#   'com',
#   'hu',
#   'xyz',
#   'gov',
#   'tech',
#   'net',
#   'gov',
#   'com',
#   'net',
#   'xyz',
#   'tech',
#   'org',
#   'xyz',
#   'gov',
#   'net',
#   'com',
#   'xyz',
#   'me',
#   'org',
#   'tech',
#   'apple',
#   'gov',
#   'net',
#   'hu',
#   'gov',
#   'gov',
#   'me',
#   'com',
#   'me',
#   'net',
#   'xyz',
#   'apple',
#   'hu',
#   'io',
#   'org',
#   'org',
#   'tech',
#   'me',
#   'apple',
#   'hu',
#   'apple',
#   'hu',
#   'tech',
#   'apple',
#   'net',
#   'me',
#   'apple',
#   'xyz',
#   'io',
#   'com',
#   'xyz',
#   'tech',
#   'io',
#   'apple',
#   'io',
#   'org',
#   'apple',
#   'io',
#   'net',
#   'org',
#   'gov',
#   'apple',
#   'hu',
#   'com',
#   'com',
#   'tech',
#   'io',
#   'org',
#   'apple',
#   'hu',
#   'tech',
#   'io',
#   'xyz',
#   'org',
#   'io',
#   'org',
#   'net',
#   'gov',
#   'net',
#   'hu',
#   'tech',
#   'net',
#   'xyz',
#   'hu',
#   'me',
#   'gov',
#   'org',
#   'tech',
#   'io',
#   'tech',
#   'me',
#   'xyz',
#   'com',
#   'hu',
#   'net',
#   'apple',
#   'com',
#   'me',
#   'tech',
#   'org',
#   'net',
#   'tech',
#   'apple',
#   'me',
#   'net',
#   'hu',
#   'hu',
#   'io',
#   'apple',
#   'tech',
#   'xyz',
#   'com',
#   'org',
#   'tech',
#   'net',
#   'net',
#   'io',
#   'apple',
#   'hu',
#   'apple',
#   'apple',
#   'xyz',
#   'com',
#   'gov',
#   'me',
#   'hu',
#   'me',
#   'hu',
#   'me',
#   'net',
#   'apple',
#   'gov',
#   'com',
#   'apple',
#   'org',
#   'com',
#   'com',
#   'hu',
#   'com',
#   'org',
#   'tech',
#   'com',
#   'com',
#   'hu',
#   'me',
#   'apple',
#   'gov',
#   'io',
#   'gov',
#   'tech',
#   'com',
#   'com',
#   'net',
#   'apple',
#   'xyz',
#   'io',
#   'xyz',
#   'com',
#   'io',
#   'io',
#   'hu',
#   'xyz',
#   'apple',
#   'xyz',
#   'org',
#   'me',
#   'net',
#   'apple',
#   'io',
#   'me',
#   'hu',
#   'tech',
#   'hu',
#   'io',
#   'net',
#   'me',
#   'me',
#   'org',
#   'com',
#   'xyz',
#   'io',
#   'xyz',
#   'com',
#   'hu',
#   'hu',
#   'apple',
#   'com',
#   'io',
#   'tech',
#   'gov',
#   'tech',
#   'tech',
#   'apple',
#   'me',
#   'xyz',
#   'com',
#   'gov',
#   'gov',
#   'hu',
#   'xyz',
#   'hu',
#   'tech',
#   'hu',
#   'com',
#   'apple',
#   'apple',
#   'apple',
#   'hu',
#   'xyz',
#   'net',
#   'org',
#   'net',
#   'gov',
#   'io',
#   'me',
#   'hu',
#   'com',
#   'hu',
#   'apple',
#   'tech',
#   'apple',
#   'net',
#   'apple',
#   'apple',
#   'org',
#   'tech',
#   'tech',
#   'org',
#   'apple',
#   'tech',
#   'com',
#   'apple',
#   'gov',
#   'me',
#   'apple',
#   'gov',
#   'com',
#   'hu',
#   'me',
#   'org',
#   'hu',
#   'me',
#   'org',
#   'io',
#   'apple',
#   'xyz',
#   'tech',
#   'gov',
#   'com',
#   'apple',
#   'me',
#   'me',
#   'tech',
#   'com',
#   'io',
#   'me',
#   'net',
#   'net',
#   'net',
#   'gov',
#   'xyz',
#   'tech',
#   'xyz',
#   'gov',
#   'org',
#   'net',
#   'xyz',
#   'net',
#   'gov',
#   'apple',
#   'tech',
#   'net',
#   'net',
#   'net',
#   'xyz',
#   'org',
#   'xyz',
#   'hu',
#   'gov',
#   'gov',
#   'me',
#   'gov',
#   'hu',
#   'tech',
#   'gov',
#   'me',
#   'me',
#   'io',
#   'me',
#   'net',
#   'me',
#   'me',
#   'gov',
#   'apple',
#   'apple',
#   'io',
#   'hu',
#   'com',
#   'tech',
#   'tech',
#   'net',
#   'apple',
#   'org',
#   'net',
#   'tech',
#   'org',
#   'org',
#   'net',
#   'hu',
#   'com',
#   'xyz',
#   'apple',
#   'io',
#   'apple',
#   'org',
#   'tech',
#   'hu',
#   'com',
#   'com',
#   'tech',
#   'me',
#   'hu',
#   'apple',
#   'io',
#   'io',
#   'io',
#   'xyz',
#   'io',
#   'org',
#   'xyz',
#   'hu',
#   'com',
#   'xyz',
#   'net',
#   'io',
#   'org',
#   'gov',
#   'me',
#   'hu',
#   'com',
#   'hu',
#   'io',
#   'tech',
#   'gov',
#   'gov',
#   'tech',
#   'hu',
#   'org',
#   'apple',
#   'xyz',
#   'org',
#   'apple',
#   'hu',
#   'net',
#   'io',
#   'net',
#   'io',
#   'apple',
#   'xyz',
#   'io',
#   'io',
#   'net',
#   'xyz',
#   'tech',
#   'me',
#   'xyz',
#   'xyz',
#   'io',
#   'apple',
#   'hu',
#   'net',
#   'net',
#   'io',
#   'net',
#   'gov',
#   'io',
#   'com',
#   'tech',
#   'net',
#   'tech',
#   'apple',
#   'apple',
#   'gov',
#   'com',
#   'net',
#   'apple',
#   'hu',
#   'com',
#   'apple',
#   'apple',
#   'xyz',
#   'net',
#   'hu',
#   'com',
#   'hu',
#   'hu',
#   'apple',
#   'gov',
#   'tech',
#   'gov',
#   'tech',
#   'hu',
#   'io',
#   'com',
#   'org',
#   'hu',
#   'hu',
#   'apple',
#   'net',
#   'tech',
#   'xyz',
#   'apple',
#   'tech',
#   'tech',
#   'io',
#   'tech',
#   'apple',
#   'io',
#   'hu',
#   'xyz',
#   'org',
#   'gov',
#   'io',
#   'tech',
#   'net',
#   'org',
#   'gov',
#   'apple',
#   'gov',
#   'com',
#   'me',
#   'me',
#   'apple',
#   'tech',
#   'hu',
#   'gov',
#   'tech',
#   'me',
#   'tech',
#   'org',
#   'tech',
#   'io',
#   'xyz',
#   'gov',
#   'hu',
#   'gov',
#   'apple',
#   'org',
#   'com',
#   'com',
#   'net',
#   'com',
#   'apple',
#   'tech',
#   'net',
#   'gov',
#   'me',
#   'xyz',
#   'net',
#   'io',
#   'hu',
#   'net',
#   'com',
#   'tech',
#   'org',
#   'apple',
#   'net',
#   'tech',
#   'org',
#   'org',
#   ...])

# %% [markdown]
# Repeat the previous exercise with this new formula and compare the length of your lists with those of the previous exercise.
# What do you notice ?
